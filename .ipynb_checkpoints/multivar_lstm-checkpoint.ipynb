# %%
import os
import numpy as np 
import math
import pandas as pd 
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import SGD
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, SimpleRNN
#"/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/data.csv"
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
# plt.style.use('fivethirtyeight')
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from numpy import concatenate

# %% [markdown]
# <h1>Make Multivariable Dataset</h1>
# <h2>Load Chinook Data</h2>

# %%
def load_data(pathname):
    salmon_data = pd.read_csv(pathname)
    salmon_data.head()
    salmon_copy = salmon_data # Create a copy for us to work with 
    salmon_copy.rename(columns = {"mo": "month", "da" : "day", "fc" : "king"}, 
          inplace = True)
    salmon_copy['date']=pd.to_datetime(salmon_copy[['year','month','day']])
#     print(salmon_copy)
    king_data = salmon_copy.filter(["date","king"], axis=1)
#     print(king_data)
    king_greater = king_data['date'].apply(pd.Timestamp) >= pd.Timestamp('01/01/1939')
    greater_than = king_data[king_greater]
    king_all = greater_than[greater_than['date'].apply(pd.Timestamp) <= pd.Timestamp('12/31/2020')]
    king_all_copy = king_all
    king_all_copy = king_all_copy.reset_index()
    king_all_copy = king_all_copy.drop('index', axis=1)
    return king_all_copy, king_data

# %%
    chris_path = '/Users/chrisshell/Desktop/Stanford/SalmonData/Use Data/passBonCS.csv'
    ismael_path = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/data.csv'
    abdul_path = '/Users/abdul/Downloads/SalmonNet/data.csv'
    king_all_copy, king_data= load_data(ismael_path)
    print(king_all_copy)
# Out:
#             date  king
# 0     1939-01-01     0
# 1     1939-01-02     0
# 2     1939-01-03     0
# 3     1939-01-04     1
# 4     1939-01-05     0
# ...          ...   ...
# 24364 2020-12-25     0
# 24365 2020-12-26     0
# 24366 2020-12-27     0
# 24367 2020-12-28     0
# 24368 2020-12-29     0
#
# [24369 rows x 2 columns]

# %%
data_copy = king_all_copy
data_copy['date']
data_copy.set_index('date', inplace=True)
data_copy.index = pd.to_datetime(data_copy.index)
data_copy = data_copy.resample('1M').sum()
data_copy
# Out:
#               king
# date
# 1939-01-31       6
# 1939-02-28      12
# 1939-03-31     121
# 1939-04-30   51410
# 1939-05-31   25159
# ...            ...
# 2020-08-31  105269
# 2020-09-30  254930
# 2020-10-31   30917
# 2020-11-30     843
# 2020-12-31       9
#
# [984 rows x 1 columns]

# %%
print(data_copy)
data_copy.shape
# Out:
#               king
# date
# 1939-01-31       6
# 1939-02-28      12
# 1939-03-31     121
# 1939-04-30   51410
# 1939-05-31   25159
# ...            ...
# 2020-08-31  105269
# 2020-09-30  254930
# 2020-10-31   30917
# 2020-11-30     843
# 2020-12-31       9
#
# [984 rows x 1 columns]
# (984, 1)

# %%
data_copy.reset_index(inplace=True)
data_copy = data_copy.rename(columns = {'index':'date'})

# %%
data_copy
# Out:
#           date    king
# 0   1939-01-31       6
# 1   1939-02-28      12
# 2   1939-03-31     121
# 3   1939-04-30   51410
# 4   1939-05-31   25159
# ..         ...     ...
# 979 2020-08-31  105269
# 980 2020-09-30  254930
# 981 2020-10-31   30917
# 982 2020-11-30     843
# 983 2020-12-31       9
#
# [984 rows x 2 columns]

# %%
master_data = data_copy
master_data
# Out:
#           date    king
# 0   1939-01-31       6
# 1   1939-02-28      12
# 2   1939-03-31     121
# 3   1939-04-30   51410
# 4   1939-05-31   25159
# ..         ...     ...
# 979 2020-08-31  105269
# 980 2020-09-30  254930
# 981 2020-10-31   30917
# 982 2020-11-30     843
# 983 2020-12-31       9
#
# [984 rows x 2 columns]

# %%
master_data = master_data[132:]

# %%
master_data
# Out:
#           date    king
# 132 1950-01-31       0
# 133 1950-02-28       0
# 134 1950-03-31      21
# 135 1950-04-30    6630
# 136 1950-05-31   50638
# ..         ...     ...
# 979 2020-08-31  105269
# 980 2020-09-30  254930
# 981 2020-10-31   30917
# 982 2020-11-30     843
# 983 2020-12-31       9
#
# [852 rows x 2 columns]

# %%
master_data.reset_index(inplace=True)

# %%
master_data = master_data.drop(labels='index', axis=1)

# %%
print(master_data)
# Out:
#           date    king
# 0   1950-01-31       0
# 1   1950-02-28       0
# 2   1950-03-31      21
# 3   1950-04-30    6630
# 4   1950-05-31   50638
# ..         ...     ...
# 847 2020-08-31  105269
# 848 2020-09-30  254930
# 849 2020-10-31   30917
# 850 2020-11-30     843
# 851 2020-12-31       9
#
# [852 rows x 2 columns]

# %%
# type(data_copy['date'])
# # data_copy['date'].astype(p)

# %% [markdown]
# <h2>Load Covariate Data and Concat to Master_Data</h2>

# %%
def load_cov_set(pathname):
    data = pd.read_csv(pathname)
    return data

# %%
ismael_path_cov = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/covariates.csv'
cov_data = load_cov_set(ismael_path_cov)
cov_data
# Out:
#      year  month  upwelling    noi   npgo   pdo  oni
# 0    1950      1        -16  2.644 -2.190 -1.61 -1.40
# 1    1950      2       -166  2.077 -1.450 -2.17 -1.20
# 2    1950      3        -49  3.091 -0.970 -1.89 -1.10
# 3    1950      4         -4  1.923 -0.860 -1.99 -1.20
# 4    1950      5         49  2.211 -0.630 -3.19 -1.10
# ..    ...    ...        ...    ...    ...   ...   ...
# 847  2020      8         43 -0.463 -1.422 -1.32 -0.57
# 848  2020      9         -1 -0.276 -1.161 -1.03 -0.89
# 849  2020     10         10  1.612 -1.476 -0.62 -1.17
# 850  2020     11        -43  1.998 -1.710 -1.58 -1.27
# 851  2020     12        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 7 columns]

# %%
upwelling = cov_data["upwelling"]
master_data = master_data.join(upwelling)
master_data
# Out:
#           date    king  upwelling
# 0   1950-01-31       0        -16
# 1   1950-02-28       0       -166
# 2   1950-03-31      21        -49
# 3   1950-04-30    6630         -4
# 4   1950-05-31   50638         49
# ..         ...     ...        ...
# 847 2020-08-31  105269         43
# 848 2020-09-30  254930         -1
# 849 2020-10-31   30917         10
# 850 2020-11-30     843        -43
# 851 2020-12-31       9        -97
#
# [852 rows x 3 columns]

# %%
noi = cov_data["noi"]
master_data = master_data.join(noi)
master_data
# Out:
#           date    king  upwelling    noi
# 0   1950-01-31       0        -16  2.644
# 1   1950-02-28       0       -166  2.077
# 2   1950-03-31      21        -49  3.091
# 3   1950-04-30    6630         -4  1.923
# 4   1950-05-31   50638         49  2.211
# ..         ...     ...        ...    ...
# 847 2020-08-31  105269         43 -0.463
# 848 2020-09-30  254930         -1 -0.276
# 849 2020-10-31   30917         10  1.612
# 850 2020-11-30     843        -43  1.998
# 851 2020-12-31       9        -97  5.098
#
# [852 rows x 4 columns]

# %%
npgo = cov_data["npgo"]
master_data = master_data.join(npgo)
master_data
# Out:
#           date    king  upwelling    noi   npgo
# 0   1950-01-31       0        -16  2.644 -2.190
# 1   1950-02-28       0       -166  2.077 -1.450
# 2   1950-03-31      21        -49  3.091 -0.970
# 3   1950-04-30    6630         -4  1.923 -0.860
# 4   1950-05-31   50638         49  2.211 -0.630
# ..         ...     ...        ...    ...    ...
# 847 2020-08-31  105269         43 -0.463 -1.422
# 848 2020-09-30  254930         -1 -0.276 -1.161
# 849 2020-10-31   30917         10  1.612 -1.476
# 850 2020-11-30     843        -43  1.998 -1.710
# 851 2020-12-31       9        -97  5.098 -1.870
#
# [852 rows x 5 columns]

# %%
pdo = cov_data["pdo"]
master_data = master_data.join(pdo)
master_data
# Out:
#           date    king  upwelling    noi   npgo   pdo
# 0   1950-01-31       0        -16  2.644 -2.190 -1.61
# 1   1950-02-28       0       -166  2.077 -1.450 -2.17
# 2   1950-03-31      21        -49  3.091 -0.970 -1.89
# 3   1950-04-30    6630         -4  1.923 -0.860 -1.99
# 4   1950-05-31   50638         49  2.211 -0.630 -3.19
# ..         ...     ...        ...    ...    ...   ...
# 847 2020-08-31  105269         43 -0.463 -1.422 -1.32
# 848 2020-09-30  254930         -1 -0.276 -1.161 -1.03
# 849 2020-10-31   30917         10  1.612 -1.476 -0.62
# 850 2020-11-30     843        -43  1.998 -1.710 -1.58
# 851 2020-12-31       9        -97  5.098 -1.870 -0.98
#
# [852 rows x 6 columns]

# %%
oni = cov_data["oni "]
master_data = master_data.join(oni)
master_data
# cov_data.columns
# Out:
#           date    king  upwelling    noi   npgo   pdo  oni
# 0   1950-01-31       0        -16  2.644 -2.190 -1.61 -1.40
# 1   1950-02-28       0       -166  2.077 -1.450 -2.17 -1.20
# 2   1950-03-31      21        -49  3.091 -0.970 -1.89 -1.10
# 3   1950-04-30    6630         -4  1.923 -0.860 -1.99 -1.20
# 4   1950-05-31   50638         49  2.211 -0.630 -3.19 -1.10
# ..         ...     ...        ...    ...    ...   ...   ...
# 847 2020-08-31  105269         43 -0.463 -1.422 -1.32 -0.57
# 848 2020-09-30  254930         -1 -0.276 -1.161 -1.03 -0.89
# 849 2020-10-31   30917         10  1.612 -1.476 -0.62 -1.17
# 850 2020-11-30     843        -43  1.998 -1.710 -1.58 -1.27
# 851 2020-12-31       9        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 7 columns]

# %%
master_data = master_data.rename(columns={"oni ": "oni"})
master_data
# Out:
#           date    king  upwelling    noi   npgo   pdo   oni
# 0   1950-01-31       0        -16  2.644 -2.190 -1.61 -1.40
# 1   1950-02-28       0       -166  2.077 -1.450 -2.17 -1.20
# 2   1950-03-31      21        -49  3.091 -0.970 -1.89 -1.10
# 3   1950-04-30    6630         -4  1.923 -0.860 -1.99 -1.20
# 4   1950-05-31   50638         49  2.211 -0.630 -3.19 -1.10
# ..         ...     ...        ...    ...    ...   ...   ...
# 847 2020-08-31  105269         43 -0.463 -1.422 -1.32 -0.57
# 848 2020-09-30  254930         -1 -0.276 -1.161 -1.03 -0.89
# 849 2020-10-31   30917         10  1.612 -1.476 -0.62 -1.17
# 850 2020-11-30     843        -43  1.998 -1.710 -1.58 -1.27
# 851 2020-12-31       9        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 7 columns]

# %%
# ismael_path_pdo = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/pdo.csv'
# pdo_data = load_cov_set(ismael_path_pdo)
# pdo_data

# %%
# master_data = data_copy

# %%
# pdo = pdo_data["PDO"]
# pdo = pdo[:984]
# pdo
# master_data = master_data.join(pdo)
# # master_data
# # master_data = master_data[:984]
# # master_data = master_data.reindex(columns=["Date", "Month", "king", "PDO"])
# # master_data

# %%
# # master_data.columns = ['year', 'month', 'king', 'pdo']
# master_data

# %%
# master_data

# %%
# master_data['year']=pd.to_datetime(master_data[['year','month']])
# master_data.set_index('date', inplace=True)
# master_data.index = pd.to_datetime(master_data.index)
# master_data

# %% [markdown]
# <h2> Load and Concat NOI data </h2>

# %%
# ismael_path_noi = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/noi.csv'
# noi_data = load_cov_set(ismael_path_noi)
# noi_data = noi_data[:877]
# noi_data = noi_data.drop(labels=0, axis=0)
# noi_data.reset_index()
# print(noi_data)
# print(noi_data['noix'])
# # noi_data = noi_data.drop(columns="index")

# %%
# noi = noi_data["noix"]
# # noi
# print(master_data)
# master_data = master_data[120:]
# print(master_data)
# master_data.reset_index()
# master_data = master_data.join(noi)

# %%
# master_data = master_data.reset_index()

# %%
# master_data
# master_data = master_data.drop(labels="index", axis=1)

# %%
# master_data.head(700)

# %%
master_data.set_index('date', inplace=True)
master_data.index = pd.to_datetime(master_data.index)
master_data
# Out:
#               king  upwelling    noi   npgo   pdo   oni
# date
# 1950-01-31       0        -16  2.644 -2.190 -1.61 -1.40
# 1950-02-28       0       -166  2.077 -1.450 -2.17 -1.20
# 1950-03-31      21        -49  3.091 -0.970 -1.89 -1.10
# 1950-04-30    6630         -4  1.923 -0.860 -1.99 -1.20
# 1950-05-31   50638         49  2.211 -0.630 -3.19 -1.10
# ...            ...        ...    ...    ...   ...   ...
# 2020-08-31  105269         43 -0.463 -1.422 -1.32 -0.57
# 2020-09-30  254930         -1 -0.276 -1.161 -1.03 -0.89
# 2020-10-31   30917         10  1.612 -1.476 -0.62 -1.17
# 2020-11-30     843        -43  1.998 -1.710 -1.58 -1.27
# 2020-12-31       9        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 6 columns]

# %%
master_data.to_csv('master_data.csv')

# %%
class CustomCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        keys = list(logs.keys())
        print("Starting training; got log keys: {}".format(keys))

    def on_train_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop training; got log keys: {}".format(keys))

    def on_epoch_begin(self, epoch, logs=None):
        keys = list(logs.keys())
        print("Start epoch {} of training; got log keys: {}".format(epoch, keys))

    def on_epoch_end(self, epoch, logs=None):
        keys = list(logs.keys())
        print("End epoch {} of training; got log keys: {}".format(epoch, keys))

    def on_test_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start testing; got log keys: {}".format(keys))

    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop testing; got log keys: {}".format(keys))

    def on_predict_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start predicting; got log keys: {}".format(keys))

    def on_predict_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop predicting; got log keys: {}".format(keys))

    def on_train_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Training: start of batch {}; got log keys: {}".format(batch, keys))

    def on_train_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Training: end of batch {}; got log keys: {}".format(batch, keys))

    def on_test_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Evaluating: start of batch {}; got log keys: {}".format(batch, keys))

    def on_test_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Evaluating: end of batch {}; got log keys: {}".format(batch, keys))

    def on_predict_batch_begin(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Predicting: start of batch {}; got log keys: {}".format(batch, keys))

    def on_predict_batch_end(self, batch, logs=None):
        keys = list(logs.keys())
        print("...Predicting: end of batch {}; got log keys: {}".format(batch, keys))

# %% [markdown]
# <h2>Let's plot each series</h2>

# %%
dataset = read_csv('master_data.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(dataset.columns[group], y=.5, loc='right')
    i += 1
plt.show()

# %% [markdown]
# <h2>Make Series into Train and Test Set with inputs and ouptuts</h2>

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=6, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# load dataset
dataset = read_csv('master_data.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,1] = encoder.fit_transform(values[:,1])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_months = 6
n_features = 6
reframed = series_to_supervised(scaled, n_months, 1)
# drop columns we don't want to predict
# reframed.drop(reframed.columns[[13]], axis=1, inplace=True)
print(reframed.head())
# Out:
#     var1(t-6)  var2(t-6)  var3(t-6)  var4(t-6)  var5(t-6)  var6(t-6)  \
# 6    0.000006   0.520913   0.710488   0.220877   0.329032   0.119048
# 7    0.000006   0.079848   0.683284   0.332829   0.238710   0.166667
# 8    0.000035   0.399240   0.731936   0.405446   0.283871   0.190476
# 9    0.009241   0.566540   0.675895   0.422088   0.267742   0.166667
# 10   0.070540   0.764259   0.689713   0.456883   0.074194   0.190476
#
#     var1(t-5)  var2(t-5)  var3(t-5)  var4(t-5)  ...  var3(t-1)  var4(t-1)  \
# 6    0.000006   0.079848   0.683284   0.332829  ...   0.632281   0.464448
# 7    0.000035   0.399240   0.731936   0.405446  ...   0.567508   0.440242
# 8    0.009241   0.566540   0.675895   0.422088  ...   0.572306   0.468986
# 9    0.070540   0.764259   0.689713   0.456883  ...   0.591786   0.461422
# 10   0.023221   0.703422   0.632281   0.464448  ...   0.461760   0.570348
#
#     var5(t-1)  var6(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)  \
# 6    0.182258   0.238095  0.045884  0.847909  0.567508  0.440242  0.000000
# 7    0.000000   0.309524  0.056366  0.638783  0.572306  0.468986  0.108065
# 8    0.108065   0.309524  0.286279  0.634981  0.591786  0.461422  0.201613
# 9    0.201613   0.333333  0.006073  0.380228  0.461760  0.570348  0.279032
# 10   0.279032   0.309524  0.000205  0.311787  0.606804  0.512859  0.354839
#
#      var6(t)
# 6   0.309524
# 7   0.309524
# 8   0.333333
# 9   0.309524
# 10  0.285714
#
# [5 rows x 42 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_months = 66 * 12 # MENTAL NOTE: IF ERROR IN MOTH TO YEAR CHECK THIS
train = values[:n_train_months, :]
test = values[n_train_months:, :]
# split into input and outputs
n_obs = n_months * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
# print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_months, n_features))
test_X = test_X.reshape((test_X.shape[0], n_months, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (792, 6, 6) (792,) (54, 6, 6) (54,)

# %%
print(train_X)
print(train_y)
# Out:
# [[[5.5716591e-06 5.2091253e-01 7.1048850e-01 2.2087744e-01 3.2903227e-01
#    1.1904764e-01]
#   [5.5716591e-06 7.9847910e-02 6.8328381e-01 3.3282903e-01 2.3870969e-01
#    1.6666666e-01]
#   [3.4822871e-05 3.9923954e-01 7.3193556e-01 4.0544629e-01 2.8387100e-01
#    1.9047621e-01]
#   [9.2405975e-03 5.6653994e-01 6.7589486e-01 4.2208773e-01 2.6774195e-01
#    1.6666666e-01]
#   [7.0539989e-02 7.6425856e-01 6.8971312e-01 4.5688349e-01 7.4193537e-02
#    1.9047621e-01]
#   [2.3221282e-02 7.0342207e-01 6.3228101e-01 4.6444780e-01 1.8225807e-01
#    2.3809527e-01]]
#
#  [[5.5716591e-06 7.9847910e-02 6.8328381e-01 3.3282903e-01 2.3870969e-01
#    1.6666666e-01]
#   [3.4822871e-05 3.9923954e-01 7.3193556e-01 4.0544629e-01 2.8387100e-01
#    1.9047621e-01]
#   [9.2405975e-03 5.6653994e-01 6.7589486e-01 4.2208773e-01 2.6774195e-01
#    1.6666666e-01]
#   [7.0539989e-02 7.6425856e-01 6.8971312e-01 4.5688349e-01 7.4193537e-02
#    1.9047621e-01]
#   [2.3221282e-02 7.0342207e-01 6.3228101e-01 4.6444780e-01 1.8225807e-01
#    2.3809527e-01]
#   [4.5884006e-02 8.4790874e-01 5.6750798e-01 4.4024205e-01 0.0000000e+00
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/2000
# 8/8 - 3s - loss: 0.0110 - val_loss: 0.0124
# Epoch 2/2000
# 8/8 - 0s - loss: 0.0122 - val_loss: 0.0099
# Epoch 3/2000
# 8/8 - 0s - loss: 0.0092 - val_loss: 0.0090
# Epoch 4/2000
# 8/8 - 0s - loss: 0.0097 - val_loss: 0.0088
# Epoch 5/2000
# 8/8 - 0s - loss: 0.0088 - val_loss: 0.0081
# Epoch 6/2000
# 8/8 - 0s - loss: 0.0089 - val_loss: 0.0081
# Epoch 7/2000
# 8/8 - 0s - loss: 0.0085 - val_loss: 0.0076
# Epoch 8/2000
# 8/8 - 0s - loss: 0.0085 - val_loss: 0.0076
# Epoch 9/2000
# 8/8 - 0s - loss: 0.0083 - val_loss: 0.0073
# Epoch 10/2000
# 8/8 - 0s - loss: 0.0082 - val_loss: 0.0072
# Epoch 11/2000
# 8/8 - 0s - loss: 0.0082 - val_loss: 0.0071
# Epoch 12/2000
# 8/8 - 0s - loss: 0.0081 - val_loss: 0.0070
# Epoch 13/2000
# 8/8 - 0s - loss: 0.0081 - val_loss: 0.0069
# Epoch 14/2000
# 8/8 - 0s - loss: 0.0080 - val_loss: 0.0068
# Epoch 15/2000
# 8/8 - 0s - loss: 0.0080 - val_loss: 0.0068
# Epoch 16/2000
# 8/8 - 0s - loss: 0.0079 - val_loss: 0.0067
# Epoch 17/2000
# 8/8 - 0s - loss: 0.0079 - val_loss: 0.0067
# Epoch 18/2000
# 8/8 - 0s - loss: 0.0079 - val_loss: 0.0066
# Epoch 19/2000
# 8/8 - 0s - loss: 0.0079 - val_loss: 0.0066
# Epoch 20/2000
# 8/8 - 0s - loss: 0.0079 - val_loss: 0.0066
# Epoch 21/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0066
# Epoch 22/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0066
# Epoch 23/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0065
# Epoch 24/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0065
# Epoch 25/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0065
# Epoch 26/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0065
# Epoch 27/2000
# 8/8 - 0s - loss: 0.0078 - val_loss: 0.0065
# Epoch 28/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 29/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 30/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 31/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 32/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 33/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 34/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 35/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 36/2000
# 8/8 - 0s - loss: 0.0077 - val_loss: 0.0065
# Epoch 37/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0065
# Epoch 38/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0065
# Epoch 39/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0065
# Epoch 40/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 41/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 42/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 43/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 44/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 45/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 46/2000
# 8/8 - 0s - loss: 0.0076 - val_loss: 0.0064
# Epoch 47/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0064
# Epoch 48/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0064
# Epoch 49/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0064
# Epoch 50/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0064
# Epoch 51/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0064
# Epoch 52/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0064
# Epoch 53/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0063
# Epoch 54/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0063
# Epoch 55/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0063
# Epoch 56/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0063
# Epoch 57/2000
# 8/8 - 0s - loss: 0.0075 - val_loss: 0.0063
# Epoch 58/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0063
# Epoch 59/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0063
# Epoch 60/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0063
# Epoch 61/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0063
# Epoch 62/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0063
# Epoch 63/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0062
# Epoch 64/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0062
# Epoch 65/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0062
# Epoch 66/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0062
# Epoch 67/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0062
# Epoch 68/2000
# 8/8 - 0s - loss: 0.0074 - val_loss: 0.0062
# Epoch 69/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0062
# Epoch 70/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0062
# Epoch 71/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 72/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 73/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 74/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 75/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 76/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 77/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0061
# Epoch 78/2000
# 8/8 - 0s - loss: 0.0073 - val_loss: 0.0060
# Epoch 79/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0060
# Epoch 80/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0060
# Epoch 81/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0060
# Epoch 82/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0060
# Epoch 83/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0060
# Epoch 84/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0060
# Epoch 85/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0059
# Epoch 86/2000
# 8/8 - 0s - loss: 0.0072 - val_loss: 0.0059
# Epoch 87/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0059
# Epoch 88/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0059
# Epoch 89/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0059
# Epoch 90/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0059
# Epoch 91/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0058
# Epoch 92/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0058
# Epoch 93/2000
# 8/8 - 0s - loss: 0.0071 - val_loss: 0.0058
# Epoch 94/2000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0058
# Epoch 95/2000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0058
# Epoch 96/2000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0058
# Epoch 97/2000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0057
# Epoch 98/2000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0057
# Epoch 99/2000
# 8/8 - 0s - loss: 0.0070 - val_loss: 0.0057
# Epoch 100/2000
# 8/8 - 0s - loss: 0.0069 - val_loss: 0.0057
# Epoch 101/2000
# 8/8 - 0s - loss: 0.0069 - val_loss: 0.0057
# Epoch 102/2000
# 8/8 - 0s - loss: 0.0069 - val_loss: 0.0056
# Epoch 103/2000
# 8/8 - 0s - loss: 0.0069 - val_loss: 0.0056
# Epoch 104/2000
# 8/8 - 0s - loss: 0.0069 - val_loss: 0.0056
# Epoch 105/2000
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0056
# Epoch 106/2000
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0056
# Epoch 107/2000
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0055
# Epoch 108/2000
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0055
# Epoch 109/2000
# 8/8 - 0s - loss: 0.0068 - val_loss: 0.0055
# Epoch 110/2000
# 8/8 - 0s - loss: 0.0067 - val_loss: 0.0055
# Epoch 111/2000
# 8/8 - 0s - loss: 0.0067 - val_loss: 0.0055
# Epoch 112/2000
# 8/8 - 0s - loss: 0.0067 - val_loss: 0.0055
# Epoch 113/2000
# 8/8 - 0s - loss: 0.0067 - val_loss: 0.0054
# Epoch 114/2000
# 8/8 - 0s - loss: 0.0066 - val_loss: 0.0054
# Epoch 115/2000
# 8/8 - 0s - loss: 0.0066 - val_loss: 0.0054
# Epoch 116/2000
# 8/8 - 0s - loss: 0.0066 - val_loss: 0.0054
# Epoch 117/2000
# 8/8 - 0s - loss: 0.0066 - val_loss: 0.0054
# Epoch 118/2000
# 8/8 - 0s - loss: 0.0065 - val_loss: 0.0054
# Epoch 119/2000
# 8/8 - 0s - loss: 0.0065 - val_loss: 0.0054
# Epoch 120/2000
# 8/8 - 0s - loss: 0.0065 - val_loss: 0.0053
# Epoch 121/2000
# 8/8 - 0s - loss: 0.0065 - val_loss: 0.0053
# Epoch 122/2000
# 8/8 - 0s - loss: 0.0064 - val_loss: 0.0053
# Epoch 123/2000
# 8/8 - 0s - loss: 0.0064 - val_loss: 0.0053
# Epoch 124/2000
# 8/8 - 0s - loss: 0.0064 - val_loss: 0.0053
# Epoch 125/2000
# 8/8 - 0s - loss: 0.0063 - val_loss: 0.0053
# Epoch 126/2000
# 8/8 - 0s - loss: 0.0063 - val_loss: 0.0053
# Epoch 127/2000
# 8/8 - 0s - loss: 0.0063 - val_loss: 0.0053
# Epoch 128/2000
# 8/8 - 0s - loss: 0.0062 - val_loss: 0.0052
# Epoch 129/2000
# 8/8 - 0s - loss: 0.0062 - val_loss: 0.0052
# Epoch 130/2000
# 8/8 - 0s - loss: 0.0062 - val_loss: 0.0052
# Epoch 131/2000
# 8/8 - 0s - loss: 0.0062 - val_loss: 0.0052
# Epoch 132/2000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0052
# Epoch 133/2000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0052
# Epoch 134/2000
# 8/8 - 0s - loss: 0.0061 - val_loss: 0.0052
# Epoch 135/2000
# 8/8 - 0s - loss: 0.0060 - val_loss: 0.0052
# Epoch 136/2000
# 8/8 - 0s - loss: 0.0060 - val_loss: 0.0051
# Epoch 137/2000
# 8/8 - 0s - loss: 0.0060 - val_loss: 0.0051
# Epoch 138/2000
# 8/8 - 0s - loss: 0.0059 - val_loss: 0.0051
# Epoch 139/2000
# 8/8 - 0s - loss: 0.0059 - val_loss: 0.0051
# Epoch 140/2000
# 8/8 - 0s - loss: 0.0059 - val_loss: 0.0051
# Epoch 141/2000
# 8/8 - 0s - loss: 0.0058 - val_loss: 0.0051
# Epoch 142/2000
# 8/8 - 0s - loss: 0.0058 - val_loss: 0.0051
# Epoch 143/2000
# 8/8 - 0s - loss: 0.0058 - val_loss: 0.0051
# Epoch 144/2000
# 8/8 - 0s - loss: 0.0057 - val_loss: 0.0051
# Epoch 145/2000
# 8/8 - 0s - loss: 0.0057 - val_loss: 0.0051
# Epoch 146/2000
# 8/8 - 0s - loss: 0.0057 - val_loss: 0.0051
# Epoch 147/2000
# 8/8 - 0s - loss: 0.0057 - val_loss: 0.0051
# Epoch 148/2000
# 8/8 - 0s - loss: 0.0056 - val_loss: 0.0051
# Epoch 149/2000
# 8/8 - 0s - loss: 0.0056 - val_loss: 0.0051
# Epoch 150/2000
# 8/8 - 0s - loss: 0.0056 - val_loss: 0.0051
# Epoch 151/2000
# 8/8 - 0s - loss: 0.0055 - val_loss: 0.0050
# Epoch 152/2000
# 8/8 - 0s - loss: 0.0055 - val_loss: 0.0050
# Epoch 153/2000
# 8/8 - 0s - loss: 0.0055 - val_loss: 0.0050
# Epoch 154/2000
# 8/8 - 0s - loss: 0.0054 - val_loss: 0.0050
# Epoch 155/2000
# 8/8 - 0s - loss: 0.0054 - val_loss: 0.0050
# Epoch 156/2000
# 8/8 - 0s - loss: 0.0054 - val_loss: 0.0050
# Epoch 157/2000
# 8/8 - 0s - loss: 0.0053 - val_loss: 0.0050
# Epoch 158/2000
# 8/8 - 0s - loss: 0.0053 - val_loss: 0.0050
# Epoch 159/2000
# 8/8 - 0s - loss: 0.0053 - val_loss: 0.0050
# Epoch 160/2000
# 8/8 - 0s - loss: 0.0052 - val_loss: 0.0050
# Epoch 161/2000
# 8/8 - 0s - loss: 0.0052 - val_loss: 0.0050
# Epoch 162/2000
# 8/8 - 0s - loss: 0.0052 - val_loss: 0.0050
# Epoch 163/2000
# 8/8 - 0s - loss: 0.0051 - val_loss: 0.0050
# Epoch 164/2000
# 8/8 - 0s - loss: 0.0051 - val_loss: 0.0050
# Epoch 165/2000
# 8/8 - 0s - loss: 0.0051 - val_loss: 0.0050
# Epoch 166/2000
# 8/8 - 0s - loss: 0.0050 - val_loss: 0.0050
# Epoch 167/2000
# 8/8 - 0s - loss: 0.0050 - val_loss: 0.0050
# Epoch 168/2000
# 8/8 - 0s - loss: 0.0050 - val_loss: 0.0050
# Epoch 169/2000
# 8/8 - 0s - loss: 0.0049 - val_loss: 0.0050
# Epoch 170/2000
# 8/8 - 0s - loss: 0.0049 - val_loss: 0.0050
# Epoch 171/2000
# 8/8 - 0s - loss: 0.0049 - val_loss: 0.0050
# Epoch 172/2000
# 8/8 - 0s - loss: 0.0048 - val_loss: 0.0050
# Epoch 173/2000
# 8/8 - 0s - loss: 0.0048 - val_loss: 0.0050
# Epoch 174/2000
# 8/8 - 0s - loss: 0.0048 - val_loss: 0.0050
# Epoch 175/2000
# 8/8 - 0s - loss: 0.0047 - val_loss: 0.0049
# Epoch 176/2000
# 8/8 - 0s - loss: 0.0047 - val_loss: 0.0049
# Epoch 177/2000
# 8/8 - 0s - loss: 0.0047 - val_loss: 0.0049
# Epoch 178/2000
# 8/8 - 0s - loss: 0.0046 - val_loss: 0.0049
# Epoch 179/2000
# 8/8 - 0s - loss: 0.0046 - val_loss: 0.0049
# Epoch 180/2000
# 8/8 - 0s - loss: 0.0046 - val_loss: 0.0049
# Epoch 181/2000
# 8/8 - 0s - loss: 0.0045 - val_loss: 0.0049
# Epoch 182/2000
# 8/8 - 0s - loss: 0.0045 - val_loss: 0.0049
# Epoch 183/2000
# 8/8 - 0s - loss: 0.0045 - val_loss: 0.0049
# Epoch 184/2000
# 8/8 - 0s - loss: 0.0044 - val_loss: 0.0049
# Epoch 185/2000
# 8/8 - 0s - loss: 0.0044 - val_loss: 0.0049
# Epoch 186/2000
# 8/8 - 0s - loss: 0.0044 - val_loss: 0.0049
# Epoch 187/2000
# 8/8 - 0s - loss: 0.0043 - val_loss: 0.0049
# Epoch 188/2000
# 8/8 - 0s - loss: 0.0043 - val_loss: 0.0049
# Epoch 189/2000
# 8/8 - 0s - loss: 0.0043 - val_loss: 0.0049
# Epoch 190/2000
# 8/8 - 0s - loss: 0.0042 - val_loss: 0.0049
# Epoch 191/2000
# 8/8 - 0s - loss: 0.0042 - val_loss: 0.0049
# Epoch 192/2000
# 8/8 - 0s - loss: 0.0042 - val_loss: 0.0049
# Epoch 193/2000
# 8/8 - 0s - loss: 0.0041 - val_loss: 0.0050
# Epoch 194/2000
# 8/8 - 0s - loss: 0.0041 - val_loss: 0.0050
# Epoch 195/2000
# 8/8 - 0s - loss: 0.0041 - val_loss: 0.0050
# Epoch 196/2000
# 8/8 - 0s - loss: 0.0040 - val_loss: 0.0050
# Epoch 197/2000
# 8/8 - 0s - loss: 0.0040 - val_loss: 0.0050
# Epoch 198/2000
# 8/8 - 0s - loss: 0.0040 - val_loss: 0.0050
# Epoch 199/2000
# 8/8 - 0s - loss: 0.0039 - val_loss: 0.0051
# Epoch 200/2000
# 8/8 - 0s - loss: 0.0039 - val_loss: 0.0051
# Epoch 201/2000
# 8/8 - 0s - loss: 0.0039 - val_loss: 0.0051
# Epoch 202/2000
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0052
# Epoch 203/2000
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0052
# Epoch 204/2000
# 8/8 - 0s - loss: 0.0038 - val_loss: 0.0053
# Epoch 205/2000
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0053
# Epoch 206/2000
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0053
# Epoch 207/2000
# 8/8 - 0s - loss: 0.0037 - val_loss: 0.0054
# Epoch 208/2000
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0055
# Epoch 209/2000
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0055
# Epoch 210/2000
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0056
# Epoch 211/2000
# 8/8 - 0s - loss: 0.0036 - val_loss: 0.0056
# Epoch 212/2000
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0057
# Epoch 213/2000
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0057
# Epoch 214/2000
# 8/8 - 0s - loss: 0.0035 - val_loss: 0.0058
# Epoch 215/2000
# 8/8 - 0s - loss: 0.0034 - val_loss: 0.0058
# Epoch 216/2000
# 8/8 - 0s - loss: 0.0034 - val_loss: 0.0058
# Epoch 217/2000
# 8/8 - 0s - loss: 0.0034 - val_loss: 0.0059
# Epoch 218/2000
# 8/8 - 0s - loss: 0.0034 - val_loss: 0.0059
# Epoch 219/2000
# 8/8 - 0s - loss: 0.0033 - val_loss: 0.0059
# Epoch 220/2000
# 8/8 - 0s - loss: 0.0033 - val_loss: 0.0060
# Epoch 221/2000
# 8/8 - 0s - loss: 0.0033 - val_loss: 0.0060
# Epoch 222/2000
# 8/8 - 0s - loss: 0.0033 - val_loss: 0.0060
# Epoch 223/2000
# 8/8 - 0s - loss: 0.0033 - val_loss: 0.0060
# Epoch 224/2000
# 8/8 - 0s - loss: 0.0032 - val_loss: 0.0060
# Epoch 225/2000
# 8/8 - 0s - loss: 0.0032 - val_loss: 0.0061
# Epoch 226/2000
# 8/8 - 0s - loss: 0.0032 - val_loss: 0.0061
# Epoch 227/2000
# 8/8 - 0s - loss: 0.0032 - val_loss: 0.0061
# Epoch 228/2000
# 8/8 - 0s - loss: 0.0032 - val_loss: 0.0061
# Epoch 229/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 230/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 231/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 232/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 233/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 234/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 235/2000
# 8/8 - 0s - loss: 0.0031 - val_loss: 0.0061
# Epoch 236/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 237/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 238/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 239/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 240/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 241/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 242/2000
# 8/8 - 0s - loss: 0.0030 - val_loss: 0.0061
# Epoch 243/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 244/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 245/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 246/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 247/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 248/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 249/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 250/2000
# 8/8 - 0s - loss: 0.0029 - val_loss: 0.0061
# Epoch 251/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0061
# Epoch 252/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0061
# Epoch 253/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0061
# Epoch 254/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 255/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 256/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 257/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 258/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 259/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 260/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 261/2000
# 8/8 - 0s - loss: 0.0028 - val_loss: 0.0060
# Epoch 262/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0060
# Epoch 263/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 264/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 265/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 266/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 267/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 268/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 269/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 270/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0059
# Epoch 271/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0058
# Epoch 272/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0058
# Epoch 273/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 274/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 275/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 276/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 277/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 278/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 279/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0058
# Epoch 280/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0057
# Epoch 281/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0057
# Epoch 282/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0057
# Epoch 283/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0057
# Epoch 284/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0057
# Epoch 285/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0057
# Epoch 286/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0057
# Epoch 287/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0057
# Epoch 288/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0057
# Epoch 289/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 290/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 291/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 292/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 293/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 294/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 295/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 296/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 297/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 298/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 299/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0056
# Epoch 300/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0056
# Epoch 301/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 302/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 303/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 304/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 305/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 306/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 307/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 308/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 309/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 310/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 311/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 312/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 313/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0055
# Epoch 314/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0054
# Epoch 315/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 316/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 317/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 318/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 319/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 320/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 321/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 322/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 323/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 324/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 325/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 326/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 327/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 328/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 329/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 330/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 331/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 332/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 333/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 334/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 335/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 336/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 337/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 338/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 339/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 340/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 341/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 342/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 343/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 344/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0053
# Epoch 345/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0055
# Epoch 346/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0051
# Epoch 347/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0059
# Epoch 348/2000
# 8/8 - 0s - loss: 0.0027 - val_loss: 0.0049
# Epoch 349/2000
# 8/8 - 0s - loss: 0.0025 - val_loss: 0.0059
# Epoch 350/2000
# 8/8 - 0s - loss: 0.0026 - val_loss: 0.0050
# Epoch 351/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 352/2000
# 8/8 - 0s - loss: 0.0024 - val_loss: 0.0053
# Epoch 353/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0054
# Epoch 354/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 355/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0054
# Epoch 356/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0054
# Epoch 357/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0055
# Epoch 358/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0053
# Epoch 359/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0055
# Epoch 360/2000
# 8/8 - 0s - loss: 0.0023 - val_loss: 0.0052
# Epoch 361/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0055
# Epoch 362/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0051
# Epoch 363/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0055
# Epoch 364/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0051
# Epoch 365/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 366/2000
# 8/8 - 0s - loss: 0.0022 - val_loss: 0.0052
# Epoch 367/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 368/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0052
# Epoch 369/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 370/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0052
# Epoch 371/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 372/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0051
# Epoch 373/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 374/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0051
# Epoch 375/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 376/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0051
# Epoch 377/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 378/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0051
# Epoch 379/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 380/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 381/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 382/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 383/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 384/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 385/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0054
# Epoch 386/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 387/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0053
# Epoch 388/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 389/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 390/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 391/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 392/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 393/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 394/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 395/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 396/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0050
# Epoch 397/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 398/2000
# 8/8 - 0s - loss: 0.0021 - val_loss: 0.0049
# Epoch 399/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 400/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 401/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 402/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 403/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 404/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 405/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 406/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 407/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0053
# Epoch 408/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 409/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0052
# Epoch 410/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 411/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0052
# Epoch 412/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 413/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0052
# Epoch 414/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 415/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0052
# Epoch 416/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 417/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0052
# Epoch 418/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 419/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0052
# Epoch 420/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0049
# Epoch 421/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0052
# Epoch 422/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0048
# Epoch 423/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0051
# Epoch 424/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0048
# Epoch 425/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0051
# Epoch 426/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0048
# Epoch 427/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0051
# Epoch 428/2000
# 8/8 - 0s - loss: 0.0020 - val_loss: 0.0048
# Epoch 429/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0051
# Epoch 430/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0048
# Epoch 431/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0051
# Epoch 432/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0048
# Epoch 433/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0051
# Epoch 434/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0047
# Epoch 435/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0050
# Epoch 436/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0047
# Epoch 437/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0050
# Epoch 438/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0047
# Epoch 439/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0050
# Epoch 440/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.0047
# Epoch 441/2000
# 8/8 - 0s - loss: 0.0019 - val_loss: 0.
2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0055
# Epoch 682/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0047
# Epoch 683/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0054
# Epoch 684/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0047
# Epoch 685/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0054
# Epoch 686/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0047
# Epoch 687/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0054
# Epoch 688/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0047
# Epoch 689/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0055
# Epoch 690/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0048
# Epoch 691/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0056
# Epoch 692/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0048
# Epoch 693/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0055
# Epoch 694/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0048
# Epoch 695/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0055
# Epoch 696/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0048
# Epoch 697/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0055
# Epoch 698/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0048
# Epoch 699/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0055
# Epoch 700/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0048
# Epoch 701/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0056
# Epoch 702/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0049
# Epoch 703/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0056
# Epoch 704/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0049
# Epoch 705/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0057
# Epoch 706/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0049
# Epoch 707/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0056
# Epoch 708/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0049
# Epoch 709/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0056
# Epoch 710/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0049
# Epoch 711/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0056
# Epoch 712/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0050
# Epoch 713/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0056
# Epoch 714/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0050
# Epoch 715/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0057
# Epoch 716/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0051
# Epoch 717/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 718/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0051
# Epoch 719/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 720/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0051
# Epoch 721/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 722/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0052
# Epoch 723/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 724/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0052
# Epoch 725/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 726/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0052
# Epoch 727/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0057
# Epoch 728/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0052
# Epoch 729/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0057
# Epoch 730/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0053
# Epoch 731/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0057
# Epoch 732/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0054
# Epoch 733/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0058
# Epoch 734/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0055
# Epoch 735/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0060
# Epoch 736/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0057
# Epoch 737/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0061
# Epoch 738/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 739/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0062
# Epoch 740/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0059
# Epoch 741/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0061
# Epoch 742/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0059
# Epoch 743/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0059
# Epoch 744/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0057
# Epoch 745/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0058
# Epoch 746/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0057
# Epoch 747/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0058
# Epoch 748/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0056
# Epoch 749/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0059
# Epoch 750/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0056
# Epoch 751/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0060
# Epoch 752/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0058
# Epoch 753/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0066
# Epoch 754/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0060
# Epoch 755/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0070
# Epoch 756/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0058
# Epoch 757/2000
# 8/8 - 0s - loss: 0.0014 - val_loss: 0.0070
# Epoch 758/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0054
# Epoch 759/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0067
# Epoch 760/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0053
# Epoch 761/2000
# 8/8 - 0s - loss: 0.0013 - val_loss: 0.0064
# Epoch 762/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0055
# Epoch 763/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0065
# Epoch 764/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0061
# Epoch 765/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0069
# Epoch 766/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0060
# Epoch 767/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0065
# Epoch 768/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0056
# Epoch 769/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0063
# Epoch 770/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0056
# Epoch 771/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0063
# Epoch 772/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0059
# Epoch 773/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0067
# Epoch 774/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0061
# Epoch 775/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0065
# Epoch 776/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0058
# Epoch 777/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0063
# Epoch 778/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0057
# Epoch 779/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0063
# Epoch 780/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0060
# Epoch 781/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0067
# Epoch 782/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0061
# Epoch 783/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0067
# Epoch 784/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0059
# Epoch 785/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0065
# Epoch 786/2000
# 8/8 - 0s - loss: 9.9090e-04 - val_loss: 0.0058
# Epoch 787/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0065
# Epoch 788/2000
# 8/8 - 0s - loss: 9.8764e-04 - val_loss: 0.0059
# Epoch 789/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0067
# Epoch 790/2000
# 8/8 - 0s - loss: 9.7216e-04 - val_loss: 0.0061
# Epoch 791/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0068
# Epoch 792/2000
# 8/8 - 0s - loss: 9.8319e-04 - val_loss: 0.0060
# Epoch 793/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0067
# Epoch 794/2000
# 8/8 - 0s - loss: 9.6624e-04 - val_loss: 0.0059
# Epoch 795/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0066
# Epoch 796/2000
# 8/8 - 0s - loss: 9.5863e-04 - val_loss: 0.0059
# Epoch 797/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0067
# Epoch 798/2000
# 8/8 - 0s - loss: 9.5120e-04 - val_loss: 0.0061
# Epoch 799/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0069
# Epoch 800/2000
# 8/8 - 0s - loss: 9.4645e-04 - val_loss: 0.0062
# Epoch 801/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0069
# Epoch 802/2000
# 8/8 - 0s - loss: 9.5189e-04 - val_loss: 0.0061
# Epoch 803/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0068
# Epoch 804/2000
# 8/8 - 0s - loss: 9.4058e-04 - val_loss: 0.0060
# Epoch 805/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0068
# Epoch 806/2000
# 8/8 - 0s - loss: 9.3181e-04 - val_loss: 0.0061
# Epoch 807/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0068
# Epoch 808/2000
# 8/8 - 0s - loss: 9.2826e-04 - val_loss: 0.0062
# Epoch 809/2000
# 8/8 - 0s - loss: 9.9773e-04 - val_loss: 0.0070
# Epoch 810/2000
# 8/8 - 0s - loss: 9.2495e-04 - val_loss: 0.0063
# Epoch 811/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0071
# Epoch 812/2000
# 8/8 - 0s - loss: 9.3318e-04 - val_loss: 0.0063
# Epoch 813/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0071
# Epoch 814/2000
# 8/8 - 0s - loss: 9.3492e-04 - val_loss: 0.0062
# Epoch 815/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0070
# Epoch 816/2000
# 8/8 - 0s - loss: 9.2927e-04 - val_loss: 0.0061
# Epoch 817/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0070
# Epoch 818/2000
# 8/8 - 0s - loss: 9.4553e-04 - val_loss: 0.0061
# Epoch 819/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0071
# Epoch 820/2000
# 8/8 - 0s - loss: 9.8711e-04 - val_loss: 0.0063
# Epoch 821/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0073
# Epoch 822/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0064
# Epoch 823/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0077
# Epoch 824/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0064
# Epoch 825/2000
# 8/8 - 0s - loss: 0.0012 - val_loss: 0.0078
# Epoch 826/2000
# 8/8 - 0s - loss: 0.0010 - val_loss: 0.0063
# Epoch 827/2000
# 8/8 - 0s - loss: 0.0011 - val_loss: 0.0076
# Epoch 828/2000
# 8/8 - 0s - loss: 9.2368e-04 - val_loss: 0.0062
# ...
# 8/8 - 0s - loss: 2.3416e-04 - val_loss: 0.0099
# Epoch 1748/2000
# 8/8 - 0s - loss: 2.3931e-04 - val_loss: 0.0097
# Epoch 1749/2000
# 8/8 - 0s - loss: 2.5472e-04 - val_loss: 0.0100
# Epoch 1750/2000
# 8/8 - 0s - loss: 2.9611e-04 - val_loss: 0.0104
# Epoch 1751/2000
# 8/8 - 0s - loss: 3.0789e-04 - val_loss: 0.0094
# Epoch 1752/2000
# 8/8 - 0s - loss: 2.8077e-04 - val_loss: 0.0102
# Epoch 1753/2000
# 8/8 - 0s - loss: 3.3259e-04 - val_loss: 0.0102
# Epoch 1754/2000
# 8/8 - 0s - loss: 3.5747e-04 - val_loss: 0.0098
# Epoch 1755/2000
# 8/8 - 0s - loss: 3.1673e-04 - val_loss: 0.0098
# Epoch 1756/2000
# 8/8 - 0s - loss: 4.6160e-04 - val_loss: 0.0103
# Epoch 1757/2000
# 8/8 - 0s - loss: 5.9514e-04 - val_loss: 0.0099
# Epoch 1758/2000
# 8/8 - 0s - loss: 4.6507e-04 - val_loss: 0.0100
# Epoch 1759/2000
# 8/8 - 0s - loss: 5.2873e-04 - val_loss: 0.0094
# Epoch 1760/2000
# 8/8 - 0s - loss: 6.4881e-04 - val_loss: 0.0108
# Epoch 1761/2000
# 8/8 - 0s - loss: 5.2631e-04 - val_loss: 0.0102
# Epoch 1762/2000
# 8/8 - 0s - loss: 5.2183e-04 - val_loss: 0.0096
# Epoch 1763/2000
# 8/8 - 0s - loss: 6.4910e-04 - val_loss: 0.0107
# Epoch 1764/2000
# 8/8 - 0s - loss: 4.7131e-04 - val_loss: 0.0102
# Epoch 1765/2000
# 8/8 - 0s - loss: 3.2866e-04 - val_loss: 0.0087
# Epoch 1766/2000
# 8/8 - 0s - loss: 4.0927e-04 - val_loss: 0.0107
# Epoch 1767/2000
# 8/8 - 0s - loss: 3.2753e-04 - val_loss: 0.0094
# Epoch 1768/2000
# 8/8 - 0s - loss: 3.1457e-04 - val_loss: 0.0096
# Epoch 1769/2000
# 8/8 - 0s - loss: 4.3188e-04 - val_loss: 0.0101
# Epoch 1770/2000
# 8/8 - 0s - loss: 4.0644e-04 - val_loss: 0.0102
# Epoch 1771/2000
# 8/8 - 0s - loss: 4.0064e-04 - val_loss: 0.0093
# Epoch 1772/2000
# 8/8 - 0s - loss: 4.1165e-04 - val_loss: 0.0103
# Epoch 1773/2000
# 8/8 - 0s - loss: 4.0390e-04 - val_loss: 0.0101
# Epoch 1774/2000
# 8/8 - 0s - loss: 4.0806e-04 - val_loss: 0.0100
# Epoch 1775/2000
# 8/8 - 0s - loss: 3.4798e-04 - val_loss: 0.0100
# Epoch 1776/2000
# 8/8 - 0s - loss: 3.5856e-04 - val_loss: 0.0098
# Epoch 1777/2000
# 8/8 - 0s - loss: 3.9856e-04 - val_loss: 0.0102
# Epoch 1778/2000
# 8/8 - 0s - loss: 3.2957e-04 - val_loss: 0.0101
# Epoch 1779/2000
# 8/8 - 0s - loss: 2.7921e-04 - val_loss: 0.0094
# Epoch 1780/2000
# 8/8 - 0s - loss: 2.6206e-04 - val_loss: 0.0104
# Epoch 1781/2000
# 8/8 - 0s - loss: 2.2756e-04 - val_loss: 0.0098
# Epoch 1782/2000
# 8/8 - 0s - loss: 2.2111e-04 - val_loss: 0.0097
# Epoch 1783/2000
# 8/8 - 0s - loss: 1.9183e-04 - val_loss: 0.0101
# Epoch 1784/2000
# 8/8 - 0s - loss: 1.8174e-04 - val_loss: 0.0098
# Epoch 1785/2000
# 8/8 - 0s - loss: 2.0227e-04 - val_loss: 0.0099
# Epoch 1786/2000
# 8/8 - 0s - loss: 1.7785e-04 - val_loss: 0.0100
# Epoch 1787/2000
# 8/8 - 0s - loss: 1.7156e-04 - val_loss: 0.0097
# Epoch 1788/2000
# 8/8 - 0s - loss: 1.9687e-04 - val_loss: 0.0101
# Epoch 1789/2000
# 8/8 - 0s - loss: 1.8297e-04 - val_loss: 0.0100
# Epoch 1790/2000
# 8/8 - 0s - loss: 1.7675e-04 - val_loss: 0.0098
# Epoch 1791/2000
# 8/8 - 0s - loss: 1.7712e-04 - val_loss: 0.0101
# Epoch 1792/2000
# 8/8 - 0s - loss: 1.7686e-04 - val_loss: 0.0100
# Epoch 1793/2000
# 8/8 - 0s - loss: 1.8586e-04 - val_loss: 0.0098
# Epoch 1794/2000
# 8/8 - 0s - loss: 1.6236e-04 - val_loss: 0.0101
# Epoch 1795/2000
# 8/8 - 0s - loss: 1.6373e-04 - val_loss: 0.0099
# Epoch 1796/2000
# 8/8 - 0s - loss: 1.9306e-04 - val_loss: 0.0100
# Epoch 1797/2000
# 8/8 - 0s - loss: 1.7435e-04 - val_loss: 0.0101
# Epoch 1798/2000
# 8/8 - 0s - loss: 1.6564e-04 - val_loss: 0.0098
# Epoch 1799/2000
# 8/8 - 0s - loss: 1.9064e-04 - val_loss: 0.0101
# Epoch 1800/2000
# 8/8 - 0s - loss: 1.8683e-04 - val_loss: 0.0101
# Epoch 1801/2000
# 8/8 - 0s - loss: 1.7734e-04 - val_loss: 0.0097
# Epoch 1802/2000
# 8/8 - 0s - loss: 1.7151e-04 - val_loss: 0.0102
# Epoch 1803/2000
# 8/8 - 0s - loss: 1.7671e-04 - val_loss: 0.0101
# Epoch 1804/2000
# 8/8 - 0s - loss: 1.8919e-04 - val_loss: 0.0099
# Epoch 1805/2000
# 8/8 - 0s - loss: 1.6648e-04 - val_loss: 0.0101
# Epoch 1806/2000
# 8/8 - 0s - loss: 1.7305e-04 - val_loss: 0.0100
# Epoch 1807/2000
# 8/8 - 0s - loss: 2.1512e-04 - val_loss: 0.0100
# Epoch 1808/2000
# 8/8 - 0s - loss: 1.9271e-04 - val_loss: 0.0102
# Epoch 1809/2000
# 8/8 - 0s - loss: 1.8273e-04 - val_loss: 0.0098
# Epoch 1810/2000
# 8/8 - 0s - loss: 2.2329e-04 - val_loss: 0.0102
# Epoch 1811/2000
# 8/8 - 0s - loss: 2.1750e-04 - val_loss: 0.0102
# Epoch 1812/2000
# 8/8 - 0s - loss: 1.9765e-04 - val_loss: 0.0097
# Epoch 1813/2000
# 8/8 - 0s - loss: 2.0601e-04 - val_loss: 0.0102
# Epoch 1814/2000
# 8/8 - 0s - loss: 2.1273e-04 - val_loss: 0.0102
# Epoch 1815/2000
# 8/8 - 0s - loss: 2.0833e-04 - val_loss: 0.0097
# Epoch 1816/2000
# 8/8 - 0s - loss: 1.8320e-04 - val_loss: 0.0102
# Epoch 1817/2000
# 8/8 - 0s - loss: 1.9291e-04 - val_loss: 0.0100
# Epoch 1818/2000
# 8/8 - 0s - loss: 2.2475e-04 - val_loss: 0.0099
# Epoch 1819/2000
# 8/8 - 0s - loss: 1.9527e-04 - val_loss: 0.0102
# Epoch 1820/2000
# 8/8 - 0s - loss: 1.9774e-04 - val_loss: 0.0099
# Epoch 1821/2000
# 8/8 - 0s - loss: 2.5679e-04 - val_loss: 0.0101
# Epoch 1822/2000
# 8/8 - 0s - loss: 2.3324e-04 - val_loss: 0.0102
# Epoch 1823/2000
# 8/8 - 0s - loss: 2.0705e-04 - val_loss: 0.0096
# Epoch 1824/2000
# 8/8 - 0s - loss: 2.4403e-04 - val_loss: 0.0103
# Epoch 1825/2000
# 8/8 - 0s - loss: 2.3536e-04 - val_loss: 0.0102
# Epoch 1826/2000
# 8/8 - 0s - loss: 2.0883e-04 - val_loss: 0.0096
# Epoch 1827/2000
# 8/8 - 0s - loss: 2.1657e-04 - val_loss: 0.0103
# Epoch 1828/2000
# 8/8 - 0s - loss: 2.2053e-04 - val_loss: 0.0101
# Epoch 1829/2000
# 8/8 - 0s - loss: 2.1274e-04 - val_loss: 0.0096
# Epoch 1830/2000
# 8/8 - 0s - loss: 1.8526e-04 - val_loss: 0.0103
# Epoch 1831/2000
# 8/8 - 0s - loss: 1.8827e-04 - val_loss: 0.0100
# Epoch 1832/2000
# 8/8 - 0s - loss: 2.1284e-04 - val_loss: 0.0099
# Epoch 1833/2000
# 8/8 - 0s - loss: 1.8843e-04 - val_loss: 0.0102
# Epoch 1834/2000
# 8/8 - 0s - loss: 1.9837e-04 - val_loss: 0.0099
# Epoch 1835/2000
# 8/8 - 0s - loss: 2.5830e-04 - val_loss: 0.0100
# Epoch 1836/2000
# 8/8 - 0s - loss: 2.2621e-04 - val_loss: 0.0102
# Epoch 1837/2000
# 8/8 - 0s - loss: 2.0142e-04 - val_loss: 0.0096
# Epoch 1838/2000
# 8/8 - 0s - loss: 2.4434e-04 - val_loss: 0.0103
# Epoch 1839/2000
# 8/8 - 0s - loss: 2.3411e-04 - val_loss: 0.0102
# Epoch 1840/2000
# 8/8 - 0s - loss: 2.1225e-04 - val_loss: 0.0097
# Epoch 1841/2000
# 8/8 - 0s - loss: 2.3935e-04 - val_loss: 0.0103
# Epoch 1842/2000
# 8/8 - 0s - loss: 2.4281e-04 - val_loss: 0.0102
# Epoch 1843/2000
# 8/8 - 0s - loss: 2.2427e-04 - val_loss: 0.0095
# Epoch 1844/2000
# 8/8 - 0s - loss: 1.9776e-04 - val_loss: 0.0104
# Epoch 1845/2000
# 8/8 - 0s - loss: 1.8957e-04 - val_loss: 0.0100
# Epoch 1846/2000
# 8/8 - 0s - loss: 1.9674e-04 - val_loss: 0.0099
# Epoch 1847/2000
# 8/8 - 0s - loss: 1.9037e-04 - val_loss: 0.0102
# Epoch 1848/2000
# 8/8 - 0s - loss: 2.1799e-04 - val_loss: 0.0101
# Epoch 1849/2000
# 8/8 - 0s - loss: 2.7097e-04 - val_loss: 0.0099
# Epoch 1850/2000
# 8/8 - 0s - loss: 2.3233e-04 - val_loss: 0.0103
# Epoch 1851/2000
# 8/8 - 0s - loss: 2.0851e-04 - val_loss: 0.0097
# Epoch 1852/2000
# 8/8 - 0s - loss: 2.4327e-04 - val_loss: 0.0104
# Epoch 1853/2000
# 8/8 - 0s - loss: 2.3441e-04 - val_loss: 0.0103
# Epoch 1854/2000
# 8/8 - 0s - loss: 2.4258e-04 - val_loss: 0.0101
# Epoch 1855/2000
# 8/8 - 0s - loss: 2.9880e-04 - val_loss: 0.0103
# Epoch 1856/2000
# 8/8 - 0s - loss: 3.0790e-04 - val_loss: 0.0105
# Epoch 1857/2000
# 8/8 - 0s - loss: 2.8089e-04 - val_loss: 0.0094
# Epoch 1858/2000
# 8/8 - 0s - loss: 2.4864e-04 - val_loss: 0.0106
# Epoch 1859/2000
# 8/8 - 0s - loss: 2.2051e-04 - val_loss: 0.0100
# Epoch 1860/2000
# 8/8 - 0s - loss: 2.1460e-04 - val_loss: 0.0103
# Epoch 1861/2000
# 8/8 - 0s - loss: 2.2599e-04 - val_loss: 0.0101
# Epoch 1862/2000
# 8/8 - 0s - loss: 2.6906e-04 - val_loss: 0.0107
# Epoch 1863/2000
# 8/8 - 0s - loss: 3.0567e-04 - val_loss: 0.0096
# Epoch 1864/2000
# 8/8 - 0s - loss: 2.5446e-04 - val_loss: 0.0106
# Epoch 1865/2000
# 8/8 - 0s - loss: 2.2000e-04 - val_loss: 0.0096
# Epoch 1866/2000
# 8/8 - 0s - loss: 2.3034e-04 - val_loss: 0.0107
# Epoch 1867/2000
# 8/8 - 0s - loss: 2.1618e-04 - val_loss: 0.0100
# Epoch 1868/2000
# 8/8 - 0s - loss: 2.3767e-04 - val_loss: 0.0106
# Epoch 1869/2000
# 8/8 - 0s - loss: 2.8784e-04 - val_loss: 0.0099
# Epoch 1870/2000
# 8/8 - 0s - loss: 2.6653e-04 - val_loss: 0.0107
# Epoch 1871/2000
# 8/8 - 0s - loss: 2.3425e-04 - val_loss: 0.0092
# Epoch 1872/2000
# 8/8 - 0s - loss: 2.1868e-04 - val_loss: 0.0108
# Epoch 1873/2000
# 8/8 - 0s - loss: 2.0032e-04 - val_loss: 0.0099
# Epoch 1874/2000
# 8/8 - 0s - loss: 1.9135e-04 - val_loss: 0.0103
# Epoch 1875/2000
# 8/8 - 0s - loss: 1.9307e-04 - val_loss: 0.0101
# Epoch 1876/2000
# 8/8 - 0s - loss: 2.0482e-04 - val_loss: 0.0105
# Epoch 1877/2000
# 8/8 - 0s - loss: 2.2310e-04 - val_loss: 0.0095
# Epoch 1878/2000
# 8/8 - 0s - loss: 1.8119e-04 - val_loss: 0.0105
# Epoch 1879/2000
# 8/8 - 0s - loss: 1.7035e-04 - val_loss: 0.0097
# Epoch 1880/2000
# 8/8 - 0s - loss: 1.9061e-04 - val_loss: 0.0103
# Epoch 1881/2000
# 8/8 - 0s - loss: 1.7892e-04 - val_loss: 0.0101
# Epoch 1882/2000
# 8/8 - 0s - loss: 1.9352e-04 - val_loss: 0.0102
# Epoch 1883/2000
# 8/8 - 0s - loss: 2.6197e-04 - val_loss: 0.0100
# Epoch 1884/2000
# 8/8 - 0s - loss: 2.2329e-04 - val_loss: 0.0103
# Epoch 1885/2000
# 8/8 - 0s - loss: 1.9597e-04 - val_loss: 0.0094
# Epoch 1886/2000
# 8/8 - 0s - loss: 2.3341e-04 - val_loss: 0.0107
# Epoch 1887/2000
# 8/8 - 0s - loss: 2.3331e-04 - val_loss: 0.0101
# Epoch 1888/2000
# 8/8 - 0s - loss: 2.2370e-04 - val_loss: 0.0100
# Epoch 1889/2000
# 8/8 - 0s - loss: 2.6044e-04 - val_loss: 0.0103
# Epoch 1890/2000
# 8/8 - 0s - loss: 2.5308e-04 - val_loss: 0.0103
# Epoch 1891/2000
# 8/8 - 0s - loss: 2.2610e-04 - val_loss: 0.0093
# Epoch 1892/2000
# 8/8 - 0s - loss: 2.0609e-04 - val_loss: 0.0106
# Epoch 1893/2000
# 8/8 - 0s - loss: 2.0503e-04 - val_loss: 0.0100
# Epoch 1894/2000
# 8/8 - 0s - loss: 2.0500e-04 - val_loss: 0.0100
# Epoch 1895/2000
# 8/8 - 0s - loss: 1.9283e-04 - val_loss: 0.0102
# Epoch 1896/2000
# 8/8 - 0s - loss: 2.1440e-04 - val_loss: 0.0102
# Epoch 1897/2000
# 8/8 - 0s - loss: 2.6038e-04 - val_loss: 0.0096
# Epoch 1898/2000
# 8/8 - 0s - loss: 2.1037e-04 - val_loss: 0.0103
# Epoch 1899/2000
# 8/8 - 0s - loss: 1.9869e-04 - val_loss: 0.0097
# Epoch 1900/2000
# 8/8 - 0s - loss: 2.5419e-04 - val_loss: 0.0105
# Epoch 1901/2000
# 8/8 - 0s - loss: 2.3815e-04 - val_loss: 0.0102
# Epoch 1902/2000
# 8/8 - 0s - loss: 2.3538e-04 - val_loss: 0.0099
# Epoch 1903/2000
# 8/8 - 0s - loss: 3.0228e-04 - val_loss: 0.0103
# Epoch 1904/2000
# 8/8 - 0s - loss: 2.7742e-04 - val_loss: 0.0103
# Epoch 1905/2000
# 8/8 - 0s - loss: 2.2532e-04 - val_loss: 0.0092
# Epoch 1906/2000
# 8/8 - 0s - loss: 2.2988e-04 - val_loss: 0.0107
# Epoch 1907/2000
# 8/8 - 0s - loss: 2.1636e-04 - val_loss: 0.0099
# Epoch 1908/2000
# 8/8 - 0s - loss: 2.0442e-04 - val_loss: 0.0099
# Epoch 1909/2000
# 8/8 - 0s - loss: 2.1605e-04 - val_loss: 0.0103
# Epoch 1910/2000
# 8/8 - 0s - loss: 2.2800e-04 - val_loss: 0.0102
# Epoch 1911/2000
# 8/8 - 0s - loss: 2.2802e-04 - val_loss: 0.0095
# Epoch 1912/2000
# 8/8 - 0s - loss: 1.8689e-04 - val_loss: 0.0104
# Epoch 1913/2000
# 8/8 - 0s - loss: 1.7732e-04 - val_loss: 0.0098
# Epoch 1914/2000
# 8/8 - 0s - loss: 2.0452e-04 - val_loss: 0.0102
# Epoch 1915/2000
# 8/8 - 0s - loss: 1.8595e-04 - val_loss: 0.0100
# Epoch 1916/2000
# 8/8 - 0s - loss: 2.0231e-04 - val_loss: 0.0101
# Epoch 1917/2000
# 8/8 - 0s - loss: 2.6533e-04 - val_loss: 0.0100
# Epoch 1918/2000
# 8/8 - 0s - loss: 2.3487e-04 - val_loss: 0.0103
# Epoch 1919/2000
# 8/8 - 0s - loss: 1.9909e-04 - val_loss: 0.0095
# Epoch 1920/2000
# 8/8 - 0s - loss: 2.3106e-04 - val_loss: 0.0106
# Epoch 1921/2000
# 8/8 - 0s - loss: 2.2089e-04 - val_loss: 0.0100
# Epoch 1922/2000
# 8/8 - 0s - loss: 2.0339e-04 - val_loss: 0.0099
# Epoch 1923/2000
# 8/8 - 0s - loss: 2.1981e-04 - val_loss: 0.0103
# Epoch 1924/2000
# 8/8 - 0s - loss: 2.3255e-04 - val_loss: 0.0103
# Epoch 1925/2000
# 8/8 - 0s - loss: 2.2086e-04 - val_loss: 0.0095
# Epoch 1926/2000
# 8/8 - 0s - loss: 1.8249e-04 - val_loss: 0.0105
# Epoch 1927/2000
# 8/8 - 0s - loss: 1.6588e-04 - val_loss: 0.0098
# Epoch 1928/2000
# 8/8 - 0s - loss: 1.8016e-04 - val_loss: 0.0100
# Epoch 1929/2000
# 8/8 - 0s - loss: 1.6877e-04 - val_loss: 0.0101
# Epoch 1930/2000
# 8/8 - 0s - loss: 1.8352e-04 - val_loss: 0.0101
# Epoch 1931/2000
# 8/8 - 0s - loss: 2.2839e-04 - val_loss: 0.0099
# Epoch 1932/2000
# 8/8 - 0s - loss: 1.9557e-04 - val_loss: 0.0104
# Epoch 1933/2000
# 8/8 - 0s - loss: 1.6732e-04 - val_loss: 0.0095
# Epoch 1934/2000
# 8/8 - 0s - loss: 2.0479e-04 - val_loss: 0.0104
# Epoch 1935/2000
# 8/8 - 0s - loss: 1.9675e-04 - val_loss: 0.0100
# Epoch 1936/2000
# 8/8 - 0s - loss: 1.8261e-04 - val_loss: 0.0099
# Epoch 1937/2000
# 8/8 - 0s - loss: 2.0783e-04 - val_loss: 0.0103
# Epoch 1938/2000
# 8/8 - 0s - loss: 2.2224e-04 - val_loss: 0.0104
# Epoch 1939/2000
# 8/8 - 0s - loss: 2.0781e-04 - val_loss: 0.0095
# Epoch 1940/2000
# 8/8 - 0s - loss: 1.8392e-04 - val_loss: 0.0105
# Epoch 1941/2000
# 8/8 - 0s - loss: 1.6533e-04 - val_loss: 0.0098
# Epoch 1942/2000
# 8/8 - 0s - loss: 1.6836e-04 - val_loss: 0.0099
# Epoch 1943/2000
# 8/8 - 0s - loss: 1.6700e-04 - val_loss: 0.0101
# Epoch 1944/2000
# 8/8 - 0s - loss: 1.9061e-04 - val_loss: 0.0102
# Epoch 1945/2000
# 8/8 - 0s - loss: 2.2099e-04 - val_loss: 0.0099
# Epoch 1946/2000
# 8/8 - 0s - loss: 1.8432e-04 - val_loss: 0.0104
# Epoch 1947/2000
# 8/8 - 0s - loss: 1.5850e-04 - val_loss: 0.0096
# Epoch 1948/2000
# 8/8 - 0s - loss: 2.0579e-04 - val_loss: 0.0103
# Epoch 1949/2000
# 8/8 - 0s - loss: 1.9951e-04 - val_loss: 0.0099
# Epoch 1950/2000
# 8/8 - 0s - loss: 1.9067e-04 - val_loss: 0.0099
# Epoch 1951/2000
# 8/8 - 0s - loss: 2.2090e-04 - val_loss: 0.0103
# Epoch 1952/2000
# 8/8 - 0s - loss: 2.3227e-04 - val_loss: 0.0105
# Epoch 1953/2000
# 8/8 - 0s - loss: 2.0787e-04 - val_loss: 0.0096
# Epoch 1954/2000
# 8/8 - 0s - loss: 2.0742e-04 - val_loss: 0.0105
# Epoch 1955/2000
# 8/8 - 0s - loss: 1.7976e-04 - val_loss: 0.0097
# Epoch 1956/2000
# 8/8 - 0s - loss: 1.6945e-04 - val_loss: 0.0098
# Epoch 1957/2000
# 8/8 - 0s - loss: 1.8338e-04 - val_loss: 0.0102
# Epoch 1958/2000
# 8/8 - 0s - loss: 2.1754e-04 - val_loss: 0.0104
# Epoch 1959/2000
# 8/8 - 0s - loss: 2.2589e-04 - val_loss: 0.0099
# Epoch 1960/2000
# 8/8 - 0s - loss: 1.8806e-04 - val_loss: 0.0105
# Epoch 1961/2000
# 8/8 - 0s - loss: 1.5814e-04 - val_loss: 0.0097
# Epoch 1962/2000
# 8/8 - 0s - loss: 1.9762e-04 - val_loss: 0.0100
# Epoch 1963/2000
# 8/8 - 0s - loss: 2.0258e-04 - val_loss: 0.0099
# Epoch 1964/2000
# 8/8 - 0s - loss: 2.1746e-04 - val_loss: 0.0101
# Epoch 1965/2000
# 8/8 - 0s - loss: 2.4872e-04 - val_loss: 0.0103
# Epoch 1966/2000
# 8/8 - 0s - loss: 2.3367e-04 - val_loss: 0.0105
# Epoch 1967/2000
# 8/8 - 0s - loss: 1.9613e-04 - val_loss: 0.0095
# Epoch 1968/2000
# 8/8 - 0s - loss: 2.4019e-04 - val_loss: 0.0104
# Epoch 1969/2000
# 8/8 - 0s - loss: 2.3715e-04 - val_loss: 0.0097
# Epoch 1970/2000
# 8/8 - 0s - loss: 2.1179e-04 - val_loss: 0.0099
# Epoch 1971/2000
# 8/8 - 0s - loss: 2.2901e-04 - val_loss: 0.0105
# Epoch 1972/2000
# 8/8 - 0s - loss: 2.7086e-04 - val_loss: 0.0105
# Epoch 1973/2000
# 8/8 - 0s - loss: 2.5505e-04 - val_loss: 0.0095
# Epoch 1974/2000
# 8/8 - 0s - loss: 2.2394e-04 - val_loss: 0.0104
# Epoch 1975/2000
# 8/8 - 0s - loss: 2.1373e-04 - val_loss: 0.0096
# Epoch 1976/2000
# 8/8 - 0s - loss: 1.8028e-04 - val_loss: 0.0101
# Epoch 1977/2000
# 8/8 - 0s - loss: 1.7994e-04 - val_loss: 0.0104
# Epoch 1978/2000
# 8/8 - 0s - loss: 2.3068e-04 - val_loss: 0.0104
# Epoch 1979/2000
# 8/8 - 0s - loss: 2.6936e-04 - val_loss: 0.0098
# Epoch 1980/2000
# 8/8 - 0s - loss: 2.1256e-04 - val_loss: 0.0102
# Epoch 1981/2000
# 8/8 - 0s - loss: 2.1575e-04 - val_loss: 0.0096
# Epoch 1982/2000
# 8/8 - 0s - loss: 1.9824e-04 - val_loss: 0.0105
# Epoch 1983/2000
# 8/8 - 0s - loss: 2.0414e-04 - val_loss: 0.0102
# Epoch 1984/2000
# 8/8 - 0s - loss: 2.2552e-04 - val_loss: 0.0103
# Epoch 1985/2000
# 8/8 - 0s - loss: 2.6655e-04 - val_loss: 0.0100
# Epoch 1986/2000
# 8/8 - 0s - loss: 2.5074e-04 - val_loss: 0.0102
# Epoch 1987/2000
# 8/8 - 0s - loss: 2.4558e-04 - val_loss: 0.0096
# Epoch 1988/2000
# 8/8 - 0s - loss: 2.1288e-04 - val_loss: 0.0108
# Epoch 1989/2000
# 8/8 - 0s - loss: 2.0662e-04 - val_loss: 0.0100
# Epoch 1990/2000
# 8/8 - 0s - loss: 2.3176e-04 - val_loss: 0.0104
# Epoch 1991/2000
# 8/8 - 0s - loss: 2.2032e-04 - val_loss: 0.0097
# Epoch 1992/2000
# 8/8 - 0s - loss: 2.5056e-04 - val_loss: 0.0102
# Epoch 1993/2000
# 8/8 - 0s - loss: 2.6581e-04 - val_loss: 0.0100
# Epoch 1994/2000
# 8/8 - 0s - loss: 2.5266e-04 - val_loss: 0.0104
# Epoch 1995/2000
# 8/8 - 0s - loss: 1.9943e-04 - val_loss: 0.0095
# Epoch 1996/2000
# 8/8 - 0s - loss: 2.5727e-04 - val_loss: 0.0107
# Epoch 1997/2000
# 8/8 - 0s - loss: 2.4868e-04 - val_loss: 0.0097
# Epoch 1998/2000
# 8/8 - 0s - loss: 2.4935e-04 - val_loss: 0.0100
# Epoch 1999/2000
# 8/8 - 0s - loss: 2.7854e-04 - val_loss: 0.0105
# Epoch 2000/2000
# 8/8 - 0s - loss: 2.9729e-04 - val_loss: 0.0103

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_months*n_features))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fab0e31f820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 72897.656

# %%
def month_to_year(month_preds):
    month_preds = month_preds[6:]
    year_preds = []
    for i in range(12, len(month_preds) + 1, 12):   
        salmon_count = np.sum(month_preds[i - 12:i])
        year_preds.append(salmon_count)
    year_preds = pd.DataFrame(year_preds, columns = ["Count"])
    return year_preds

def return_rmse(test, predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
preds = month_to_year(inv_yhat)
actual = month_to_year(inv_y)
print(preds)
print(actual)
# Out:
#          Count
# 0  812492.5625
# 1  529001.2500
# 2  606144.5625
# 3  685789.0625
#       Count
# 0  488981.0
# 1  336030.0
# 2  381773.0
# 3  535746.0

# %%
bs_chris_path = '/Users/chrisshell/Desktop/Stanford/SalmonData/Forecast Data Update.csv'
bs_ismael_path = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/forecast_data_17_20.csv'
bs_abdul_path = '/Users/abdul/Downloads/SalmonNet/Forecast Data Update.csv'
baseline_data = pd.read_csv(bs_ismael_path)
traditional = pd.DataFrame(baseline_data["Count"])
print(traditional)
# Out:
#     Count
# 0  498710
# 1  439060
# 2  294840
# 3  347600

# %%
return_rmse(actual, traditional)
# Out:
# The root mean squared error is 115829.72216361394.

# %%
return_rmse(actual, preds)
# Out:
# The root mean squared error is 231707.3332141347.

# %%
# def create_train_test(king_all):
#     king_training_parse = king_all['date'].apply(pd.Timestamp) <= pd.Timestamp('12/31/2015')
#     king_training = king_all[king_training_parse]
#     king_training = king_training.reset_index()
#     king_training = king_training.drop('index', axis=1)
    
#     king_test_parse = king_all['date'].apply(pd.Timestamp) > pd.Timestamp('12/31/2015')
#     king_test = king_all[king_test_parse]
#     king_test = king_test.reset_index()
#     king_test = king_test.drop('index', axis=1)
#     print(king_test.shape)
    
#     # Normalizing Data
#     king_training[king_training["king"] < 0] = 0 
# #     print('max val king_train:')
#     print(max(king_training['king']))
#     king_test[king_test["king"] < 0] = 0
# #     print('max val king_test:')
#     print(max(king_test['king']))
#     king_train_pre = king_training["king"].to_frame()
# #     print(king_train_norm)
#     king_test_pre = king_test["king"].to_frame()
#     scaler = MinMaxScaler(feature_range=(0, 1))
#     king_train_norm = scaler.fit_transform(king_train_pre)
#     king_test_norm = scaler.fit_transform(king_test_pre)
#     print('king_test_norm')
#     print(king_test_norm.shape)
#     print('king_train_norm')
#     print(king_train_norm.shape)
#     #king_train_norm = (king_training["king"] - np.min(king_training["king"])) / (np.max(king_training["king"]) - np.min(king_training["king"]))
#     #print(type(king_train_norm))
#     #king_train_norm = king_train_norm.to_frame()
#     x_train = []
#     y_train = []
#     x_test = []
#     y_test = []
#     y_test_not_norm = []
#     y_train_not_norm = []
    
#     # Todo: Experiment with input size of input (ex. 30 days)
    
#     for i in range(6,924): # 30
#         x_train.append(king_train_norm[i-6:i])
#         y_train.append(king_train_norm[i])
#     for i in range(6, 60):
#         x_test.append(king_test_norm[i-6:i])
#         y_test.append(king_test_norm[i])
    
#     # make y_test_not_norm
#     for i in range(6, 60):
#         y_test_not_norm.append(king_test['king'][i])
#     for i in range(6,924): # 30
#         y_train_not_norm.append(king_training['king'][i])
        
#     return x_train, y_train, x_test, y_test, scaler, y_test_not_norm, y_train_not_norm

# %%
x_train, y_train, x_test, y_test, scaler, y_test_not_norm, y_train_not_norm = create_train_test(data_copy)
x_train = np.array(x_train)
x_test = np.array(x_test)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1)).astype(np.float32)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
y_train = np.array(y_train)
y_test = np.array(y_test)
y_test_not_norm = np.array(y_test_not_norm)
print(y_test.shape)
y_test_not_norm = y_test_not_norm.reshape((y_test_not_norm.shape[0], 1))
print(y_test_not_norm.shape)
y_train_not_norm = np.array(y_train_not_norm)
y_train_not_norm = y_train_not_norm.reshape((y_train_not_norm.shape[0], 1))
print(y_train_not_norm.shape)
print(y_train.shape)
# Out:
# (60, 2)
# 717915
# 294611
# king_test_norm
# (60, 1)
# king_train_norm
# (924, 1)
# (54, 1)
# (54, 1)
# (918, 1)
# (918, 1)

# %%
# def load_pdo(pathname):
#     pdo_data = pd.read_csv(pathname)
# #     print(pdo_data.head())
#     return pdo_data

# %%
# ismael_path_pdo = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/pdo.csv'
# pdo_data = load_pdo(ismael_path_pdo)

# %%
# pdo = pdo_data["PDO"]
# data_copy = data_copy.join(pdo)

# %%
# pdo_data

# %%
# print(data_copy)
