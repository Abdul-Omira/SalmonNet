# %%
import os
import numpy as np 
import math
import pandas as pd 
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import SGD
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, SimpleRNN
#"/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/data.csv"
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
# plt.style.use('fivethirtyeight')
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from numpy import concatenate

# %% [markdown]
# <h1>Make Multivariable Dataset</h1>
# <h2>Load Chinook Data</h2>

# %%
def load_data(pathname):
    salmon_data = pd.read_csv(pathname)
    salmon_data.head()
    salmon_copy = salmon_data # Create a copy for us to work with 
    salmon_copy.rename(columns = {"mo": "month", "da" : "day", "fc" : "king"}, 
          inplace = True)
    salmon_copy['date']=pd.to_datetime(salmon_copy[['year','month','day']])
#     print(salmon_copy)
    king_data = salmon_copy.filter(["date","king"], axis=1)
#     print(king_data)
    king_greater = king_data['date'].apply(pd.Timestamp) >= pd.Timestamp('01/01/1939')
    greater_than = king_data[king_greater]
    king_all = greater_than[greater_than['date'].apply(pd.Timestamp) <= pd.Timestamp('12/31/2020')]
    king_all_copy = king_all
    king_all_copy = king_all_copy.reset_index()
    king_all_copy = king_all_copy.drop('index', axis=1)
    return king_all_copy, king_data

# %%
    chris_path = '/Users/chrisshell/Desktop/Stanford/SalmonData/Use Data/passBonCS.csv'
    ismael_path = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/data.csv'
    abdul_path = '/Users/abdul/Downloads/SalmonNet/data.csv'
    king_all_copy, king_data= load_data(chris_path)
    print(king_all_copy)
# Out:
#             date  king
# 0     1939-01-01     0
# 1     1939-01-02     0
# 2     1939-01-03     0
# 3     1939-01-04     1
# 4     1939-01-05     0
# ...          ...   ...
# 24364 2020-12-25     0
# 24365 2020-12-26     0
# 24366 2020-12-27     0
# 24367 2020-12-28     0
# 24368 2020-12-29     0
#
# [24369 rows x 2 columns]

# %%
data_copy = king_all_copy
print(data_copy['date'])
data_copy.set_index('date', inplace=True)
data_copy.index = pd.to_datetime(data_copy.index)
data_copy = data_copy.resample('1M').sum()
data_copy
# Out:
# 0       1939-01-01
# 1       1939-01-02
# 2       1939-01-03
# 3       1939-01-04
# 4       1939-01-05
#            ...
# 24364   2020-12-25
# 24365   2020-12-26
# 24366   2020-12-27
# 24367   2020-12-28
# 24368   2020-12-29
# Name: date, Length: 24369, dtype: datetime64[ns]
#               king
# date
# 1939-01-31       6
# 1939-02-28      12
# 1939-03-31     121
# 1939-04-30   51410
# 1939-05-31   25159
# ...            ...
# 2020-08-31  105269
# 2020-09-30  254930
# 2020-10-31   30917
# 2020-11-30     843
# 2020-12-31       9
#
# [984 rows x 1 columns]

# %%
print(data_copy)
data_copy.shape
# Out:
#               king
# date
# 1939-01-31       6
# 1939-02-28      12
# 1939-03-31     121
# 1939-04-30   51410
# 1939-05-31   25159
# ...            ...
# 2020-08-31  105269
# 2020-09-30  254930
# 2020-10-31   30917
# 2020-11-30     843
# 2020-12-31       9
#
# [984 rows x 1 columns]
# (984, 1)

# %%
data_copy.reset_index(inplace=True)
data_copy = data_copy.rename(columns = {'index':'date'})

# %%
data_copy
# Out:
#           date    king
# 0   1939-01-31       6
# 1   1939-02-28      12
# 2   1939-03-31     121
# 3   1939-04-30   51410
# 4   1939-05-31   25159
# ..         ...     ...
# 979 2020-08-31  105269
# 980 2020-09-30  254930
# 981 2020-10-31   30917
# 982 2020-11-30     843
# 983 2020-12-31       9
#
# [984 rows x 2 columns]

# %%
master_data = data_copy
master_data
# Out:
#           date    king
# 0   1939-01-31       6
# 1   1939-02-28      12
# 2   1939-03-31     121
# 3   1939-04-30   51410
# 4   1939-05-31   25159
# ..         ...     ...
# 979 2020-08-31  105269
# 980 2020-09-30  254930
# 981 2020-10-31   30917
# 982 2020-11-30     843
# 983 2020-12-31       9
#
# [984 rows x 2 columns]

# %%
master_data = master_data[132:]

# %%
master_data
# Out:
#           date    king
# 132 1950-01-31       0
# 133 1950-02-28       0
# 134 1950-03-31      21
# 135 1950-04-30    6630
# 136 1950-05-31   50638
# ..         ...     ...
# 979 2020-08-31  105269
# 980 2020-09-30  254930
# 981 2020-10-31   30917
# 982 2020-11-30     843
# 983 2020-12-31       9
#
# [852 rows x 2 columns]

# %%
master_data.reset_index(inplace=True)

# %%
master_data = master_data.drop(labels='index', axis=1)

# %%
print(master_data)
# Out:
#           date    king
# 0   1950-01-31       0
# 1   1950-02-28       0
# 2   1950-03-31      21
# 3   1950-04-30    6630
# 4   1950-05-31   50638
# ..         ...     ...
# 847 2020-08-31  105269
# 848 2020-09-30  254930
# 849 2020-10-31   30917
# 850 2020-11-30     843
# 851 2020-12-31       9
#
# [852 rows x 2 columns]

# %%
# type(data_copy['date'])
# # data_copy['date'].astype(p)

# %% [markdown]
# <h2>Load Covariate Data and Concat to Master_Data</h2>

# %%
def load_cov_set(pathname):
    data = pd.read_csv(pathname)
    return data

# %%
ismael_path_cov = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/covariates.csv'
chris_path_cov = '/Users/chrisshell/Desktop/Stanford/SalmonData/Environmental Variables/salmon_env_use.csv'
cov_data = load_cov_set(chris_path_cov)
cov_data
# Out:
#      year  month  upwelling    noi   npgo   pdo  oni
# 0    1950      1        -16  2.644 -2.190 -1.61 -1.40
# 1    1950      2       -166  2.077 -1.450 -2.17 -1.20
# 2    1950      3        -49  3.091 -0.970 -1.89 -1.10
# 3    1950      4         -4  1.923 -0.860 -1.99 -1.20
# 4    1950      5         49  2.211 -0.630 -3.19 -1.10
# ..    ...    ...        ...    ...    ...   ...   ...
# 847  2020      8         43 -0.463 -1.422 -1.32 -0.57
# 848  2020      9         -1 -0.276 -1.161 -1.03 -0.89
# 849  2020     10         10  1.612 -1.476 -0.62 -1.17
# 850  2020     11        -43  1.998 -1.710 -1.58 -1.27
# 851  2020     12        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 7 columns]

# %%
upwelling = cov_data["upwelling"]
master_data = master_data.join(upwelling)
master_data
# Out:
#           date    king  upwelling
# 0   1950-01-31       0        -16
# 1   1950-02-28       0       -166
# 2   1950-03-31      21        -49
# 3   1950-04-30    6630         -4
# 4   1950-05-31   50638         49
# ..         ...     ...        ...
# 847 2020-08-31  105269         43
# 848 2020-09-30  254930         -1
# 849 2020-10-31   30917         10
# 850 2020-11-30     843        -43
# 851 2020-12-31       9        -97
#
# [852 rows x 3 columns]

# %%
noi = cov_data["noi"]
master_data = master_data.join(noi)
master_data
# Out:
#           date    king  upwelling    noi
# 0   1950-01-31       0        -16  2.644
# 1   1950-02-28       0       -166  2.077
# 2   1950-03-31      21        -49  3.091
# 3   1950-04-30    6630         -4  1.923
# 4   1950-05-31   50638         49  2.211
# ..         ...     ...        ...    ...
# 847 2020-08-31  105269         43 -0.463
# 848 2020-09-30  254930         -1 -0.276
# 849 2020-10-31   30917         10  1.612
# 850 2020-11-30     843        -43  1.998
# 851 2020-12-31       9        -97  5.098
#
# [852 rows x 4 columns]

# %%
npgo = cov_data["npgo"]
master_data = master_data.join(npgo)
master_data
# Out:
#           date    king  upwelling    noi   npgo
# 0   1950-01-31       0        -16  2.644 -2.190
# 1   1950-02-28       0       -166  2.077 -1.450
# 2   1950-03-31      21        -49  3.091 -0.970
# 3   1950-04-30    6630         -4  1.923 -0.860
# 4   1950-05-31   50638         49  2.211 -0.630
# ..         ...     ...        ...    ...    ...
# 847 2020-08-31  105269         43 -0.463 -1.422
# 848 2020-09-30  254930         -1 -0.276 -1.161
# 849 2020-10-31   30917         10  1.612 -1.476
# 850 2020-11-30     843        -43  1.998 -1.710
# 851 2020-12-31       9        -97  5.098 -1.870
#
# [852 rows x 5 columns]

# %%
pdo = cov_data["pdo"]
master_data = master_data.join(pdo)
master_data
# Out:
#           date    king  upwelling    noi   npgo   pdo
# 0   1950-01-31       0        -16  2.644 -2.190 -1.61
# 1   1950-02-28       0       -166  2.077 -1.450 -2.17
# 2   1950-03-31      21        -49  3.091 -0.970 -1.89
# 3   1950-04-30    6630         -4  1.923 -0.860 -1.99
# 4   1950-05-31   50638         49  2.211 -0.630 -3.19
# ..         ...     ...        ...    ...    ...   ...
# 847 2020-08-31  105269         43 -0.463 -1.422 -1.32
# 848 2020-09-30  254930         -1 -0.276 -1.161 -1.03
# 849 2020-10-31   30917         10  1.612 -1.476 -0.62
# 850 2020-11-30     843        -43  1.998 -1.710 -1.58
# 851 2020-12-31       9        -97  5.098 -1.870 -0.98
#
# [852 rows x 6 columns]

# %%
oni = cov_data["oni "]
master_data = master_data.join(oni)
master_data
# cov_data.columns
# Out:
#           date    king  upwelling    noi   npgo   pdo  oni
# 0   1950-01-31       0        -16  2.644 -2.190 -1.61 -1.40
# 1   1950-02-28       0       -166  2.077 -1.450 -2.17 -1.20
# 2   1950-03-31      21        -49  3.091 -0.970 -1.89 -1.10
# 3   1950-04-30    6630         -4  1.923 -0.860 -1.99 -1.20
# 4   1950-05-31   50638         49  2.211 -0.630 -3.19 -1.10
# ..         ...     ...        ...    ...    ...   ...   ...
# 847 2020-08-31  105269         43 -0.463 -1.422 -1.32 -0.57
# 848 2020-09-30  254930         -1 -0.276 -1.161 -1.03 -0.89
# 849 2020-10-31   30917         10  1.612 -1.476 -0.62 -1.17
# 850 2020-11-30     843        -43  1.998 -1.710 -1.58 -1.27
# 851 2020-12-31       9        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 7 columns]

# %%
master_data = master_data.rename(columns={"oni ": "oni"})
master_data
# Out:
#           date    king  upwelling    noi   npgo   pdo   oni
# 0   1950-01-31       0        -16  2.644 -2.190 -1.61 -1.40
# 1   1950-02-28       0       -166  2.077 -1.450 -2.17 -1.20
# 2   1950-03-31      21        -49  3.091 -0.970 -1.89 -1.10
# 3   1950-04-30    6630         -4  1.923 -0.860 -1.99 -1.20
# 4   1950-05-31   50638         49  2.211 -0.630 -3.19 -1.10
# ..         ...     ...        ...    ...    ...   ...   ...
# 847 2020-08-31  105269         43 -0.463 -1.422 -1.32 -0.57
# 848 2020-09-30  254930         -1 -0.276 -1.161 -1.03 -0.89
# 849 2020-10-31   30917         10  1.612 -1.476 -0.62 -1.17
# 850 2020-11-30     843        -43  1.998 -1.710 -1.58 -1.27
# 851 2020-12-31       9        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 7 columns]

# %%
# ismael_path_pdo = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/pdo.csv'
# pdo_data = load_cov_set(ismael_path_pdo)
# pdo_data

# %%
# master_data = data_copy

# %%
# pdo = pdo_data["PDO"]
# pdo = pdo[:984]
# pdo
# master_data = master_data.join(pdo)
# # master_data
# # master_data = master_data[:984]
# # master_data = master_data.reindex(columns=["Date", "Month", "king", "PDO"])
# # master_data

# %%
# # master_data.columns = ['year', 'month', 'king', 'pdo']
# master_data

# %%
# master_data

# %%
# master_data['year']=pd.to_datetime(master_data[['year','month']])
# master_data.set_index('date', inplace=True)
# master_data.index = pd.to_datetime(master_data.index)
# master_data

# %% [markdown]
# <h2> Load and Concat NOI data </h2>

# %%
# ismael_path_noi = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/noi.csv'
# noi_data = load_cov_set(ismael_path_noi)
# noi_data = noi_data[:877]
# noi_data = noi_data.drop(labels=0, axis=0)
# noi_data.reset_index()
# print(noi_data)
# print(noi_data['noix'])
# # noi_data = noi_data.drop(columns="index")

# %%
# noi = noi_data["noix"]
# # noi
# print(master_data)
# master_data = master_data[120:]
# print(master_data)
# master_data.reset_index()
# master_data = master_data.join(noi)

# %%
# master_data = master_data.reset_index()

# %%
# master_data
# master_data = master_data.drop(labels="index", axis=1)

# %%
# master_data.head(700)

# %%
master_data.set_index('date', inplace=True)
master_data.index = pd.to_datetime(master_data.index)
master_data
# Out:
#               king  upwelling    noi   npgo   pdo   oni
# date
# 1950-01-31       0        -16  2.644 -2.190 -1.61 -1.40
# 1950-02-28       0       -166  2.077 -1.450 -2.17 -1.20
# 1950-03-31      21        -49  3.091 -0.970 -1.89 -1.10
# 1950-04-30    6630         -4  1.923 -0.860 -1.99 -1.20
# 1950-05-31   50638         49  2.211 -0.630 -3.19 -1.10
# ...            ...        ...    ...    ...   ...   ...
# 2020-08-31  105269         43 -0.463 -1.422 -1.32 -0.57
# 2020-09-30  254930         -1 -0.276 -1.161 -1.03 -0.89
# 2020-10-31   30917         10  1.612 -1.476 -0.62 -1.17
# 2020-11-30     843        -43  1.998 -1.710 -1.58 -1.27
# 2020-12-31       9        -97  5.098 -1.870 -0.98 -1.19
#
# [852 rows x 6 columns]

# %%
master_data.to_csv('master_data.csv')

# %%
checkpoint_filepath = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/checkpoint'
chris_checkpoint_path = '/Users/chrisshell/Desktop/Stanford/SalmonData/Checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %% [markdown]
# <h2>Let's plot each series</h2>

# %%
dataset = read_csv('master_data.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(dataset.columns[group], y=.5, loc='right')
    i += 1
plt.show()

# %% [markdown]
# <h2>Make Series into Train and Test Set with inputs and ouptuts</h2>

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=6, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# load dataset
dataset = read_csv('master_data.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,1] = encoder.fit_transform(values[:,1])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
n_months = 6
n_features = 6
reframed = series_to_supervised(scaled, n_months, 1)
# drop columns we don't want to predict
# reframed.drop(reframed.columns[[13]], axis=1, inplace=True)
print(reframed.head())
# Out:
#     var1(t-6)  var2(t-6)  var3(t-6)  var4(t-6)  var5(t-6)  var6(t-6)  \
# 6    0.000006   0.520913   0.710488   0.220877   0.329032   0.119048
# 7    0.000006   0.079848   0.683284   0.332829   0.238710   0.166667
# 8    0.000035   0.399240   0.731936   0.405446   0.283871   0.190476
# 9    0.009241   0.566540   0.675895   0.422088   0.267742   0.166667
# 10   0.070540   0.764259   0.689713   0.456883   0.074194   0.190476
#
#     var1(t-5)  var2(t-5)  var3(t-5)  var4(t-5)  ...  var3(t-1)  var4(t-1)  \
# 6    0.000006   0.079848   0.683284   0.332829  ...   0.632281   0.464448
# 7    0.000035   0.399240   0.731936   0.405446  ...   0.567508   0.440242
# 8    0.009241   0.566540   0.675895   0.422088  ...   0.572306   0.468986
# 9    0.070540   0.764259   0.689713   0.456883  ...   0.591786   0.461422
# 10   0.023221   0.703422   0.632281   0.464448  ...   0.461760   0.570348
#
#     var5(t-1)  var6(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)  \
# 6    0.182258   0.238095  0.045884  0.847909  0.567508  0.440242  0.000000
# 7    0.000000   0.309524  0.056366  0.638783  0.572306  0.468986  0.108065
# 8    0.108065   0.309524  0.286279  0.634981  0.591786  0.461422  0.201613
# 9    0.201613   0.333333  0.006073  0.380228  0.461760  0.570348  0.279032
# 10   0.279032   0.309524  0.000205  0.311787  0.606804  0.512859  0.354839
#
#      var6(t)
# 6   0.309524
# 7   0.309524
# 8   0.333333
# 9   0.309524
# 10  0.285714
#
# [5 rows x 42 columns]

# %%
# split into train and test sets
values = reframed.values
n_train_months = 66 * 12 # MENTAL NOTE: IF ERROR IN MOTH TO YEAR CHECK THIS
train = values[:n_train_months, :]
test = values[n_train_months:, :]
# split into input and outputs
n_obs = n_months * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
# print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_months, n_features))
test_X = test_X.reshape((test_X.shape[0], n_months, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (792, 6, 6) (792,) (54, 6, 6) (54,)

# %%
X_train, X_dev, y_train, y_dev = train_test_split(train_X, train_y, test_size=0.10, shuffle=False)

# %%
print(X_dev.shape)
print(y_dev.shape)
print(X_train.shape)
print(y_train.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (80, 6, 6)
# (80,)
# (712, 6, 6)
# (712,)
# (54, 6, 6)
# (54,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(LSTM(1))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam',  metrics=[tf.keras.metrics.RootMeanSquaredError()])
# fit network
#  
history = model.fit(train_X, train_y, epochs=1000, batch_size=100, validation_data=(X_dev, y_dev), verbose=2, shuffle=False, callbacks=[model_checkpoint_callback])
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='dev')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 8/8 - 9s - loss: 0.0100 - root_mean_squared_error: 0.0999 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2025
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 2/1000
# 8/8 - 0s - loss: 0.0096 - root_mean_squared_error: 0.0982 - val_loss: 0.0409 - val_root_mean_squared_error: 0.2023
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 3/1000
# 8/8 - 0s - loss: 0.0094 - root_mean_squared_error: 0.0972 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2058
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 4/1000
# 8/8 - 0s - loss: 0.0093 - root_mean_squared_error: 0.0964 - val_loss: 0.0422 - val_root_mean_squared_error: 0.2053
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 5/1000
# 8/8 - 0s - loss: 0.0092 - root_mean_squared_error: 0.0960 - val_loss: 0.0415 - val_root_mean_squared_error: 0.2036
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 6/1000
# 8/8 - 0s - loss: 0.0092 - root_mean_squared_error: 0.0962 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2034
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 7/1000
# 8/8 - 0s - loss: 0.0092 - root_mean_squared_error: 0.0961 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2040
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 8/1000
# 8/8 - 0s - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0416 - val_root_mean_squared_error: 0.2039
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 9/1000
# 8/8 - 0s - loss: 0.0091 - root_mean_squared_error: 0.0955 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2033
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 10/1000
# 8/8 - 0s - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2031
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 11/1000
# 8/8 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0412 - val_root_mean_squared_error: 0.2029
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 12/1000
# 8/8 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0947 - val_loss: 0.0410 - val_root_mean_squared_error: 0.2024
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 13/1000
# 8/8 - 0s - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0408 - val_root_mean_squared_error: 0.2021
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 14/1000
# 8/8 - 0s - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2017
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 15/1000
# 8/8 - 0s - loss: 0.0089 - root_mean_squared_error: 0.0941 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2014
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 16/1000
# 8/8 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0404 - val_root_mean_squared_error: 0.2011
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 17/1000
# 8/8 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0403 - val_root_mean_squared_error: 0.2007
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 18/1000
# 8/8 - 0s - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0401 - val_root_mean_squared_error: 0.2002
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 19/1000
# 8/8 - 0s - loss: 0.0087 - root_mean_squared_error: 0.0930 - val_loss: 0.0399 - val_root_mean_squared_error: 0.1997
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 20/1000
# 8/8 - 0s - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0396 - val_root_mean_squared_error: 0.1991
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 21/1000
# 8/8 - 0s - loss: 0.0085 - root_mean_squared_error: 0.0921 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1983
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 22/1000
# 8/8 - 0s - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1974
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 23/1000
# 8/8 - 0s - loss: 0.0082 - root_mean_squared_error: 0.0908 - val_loss: 0.0384 - val_root_mean_squared_error: 0.1959
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 24/1000
# 8/8 - 0s - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0375 - val_root_mean_squared_error: 0.1936
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 25/1000
# 8/8 - 0s - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1913
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 26/1000
# 8/8 - 0s - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1898
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 27/1000
# 8/8 - 0s - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 28/1000
# 8/8 - 0s - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1851
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 29/1000
# 8/8 - 0s - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.0333 - val_root_mean_squared_error: 0.1824
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 30/1000
# 8/8 - 0s - loss: 0.0068 - root_mean_squared_error: 0.0827 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1810
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 31/1000
# 8/8 - 0s - loss: 0.0067 - root_mean_squared_error: 0.0817 - val_loss: 0.0322 - val_root_mean_squared_error: 0.1794
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 32/1000
# 8/8 - 0s - loss: 0.0064 - root_mean_squared_error: 0.0802 - val_loss: 0.0301 - val_root_mean_squared_error: 0.1734
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 33/1000
# 8/8 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0790 - val_loss: 0.0282 - val_root_mean_squared_error: 0.1680
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 34/1000
# 8/8 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0789 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1666
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 35/1000
# 8/8 - 0s - loss: 0.0063 - root_mean_squared_error: 0.0791 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1687
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 36/1000
# 8/8 - 0s - loss: 0.0061 - root_mean_squared_error: 0.0778 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1661
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 37/1000
# 8/8 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1616
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 38/1000
# 8/8 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0775 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1617
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 39/1000
# 8/8 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0770 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1615
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 40/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1595
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 41/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0763 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1589
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 42/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 43/1000
# 8/8 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0757 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1567
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 44/1000
# 8/8 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0754 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1561
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 45/1000
# 8/8 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1547
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 46/1000
# 8/8 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1542
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 47/1000
# 8/8 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0744 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 48/1000
# 8/8 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0743 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1521
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 49/1000
# 8/8 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0738 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1507
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 50/1000
# 8/8 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0735 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1495
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 51/1000
# 8/8 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 52/1000
# 8/8 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0728 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1468
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 53/1000
# 8/8 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 54/1000
# 8/8 - 0s - loss: 0.0052 - root_mean_squared_error: 0.0722 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1444
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 55/1000
# 8/8 - 0s - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 56/1000
# 8/8 - 0s - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1426
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 57/1000
# 8/8 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0717 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1422
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 58/1000
# 8/8 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1413
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 59/1000
# 8/8 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0198 - val_root_mean_squared_error: 0.1406
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 60/1000
# 8/8 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0711 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1402
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 61/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0708 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1398
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 62/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1391
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 63/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0706 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1386
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 64/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1384
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 65/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 66/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 67/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0699 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1372
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 68/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1368
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 69/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0697 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1365
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 70/1000
# 8/8 - 0s - loss: 0.0048 - root_mean_squared_error: 0.0695 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1361
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 71/1000
# 8/8 - 0s - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1357
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 72/1000
# 8/8 - 0s - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1354
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 73/1000
# 8/8 - 0s - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1349
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 74/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 75/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0687 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1339
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 76/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1335
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 77/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1330
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 78/1000
# 8/8 - 0s - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 79/1000
# 8/8 - 0s - loss: 0.0046 - root_mean_squared_error: 0.0675 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1322
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 80/1000
# 8/8 - 0s - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1314
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 81/1000
# 8/8 - 0s - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 82/1000
# 8/8 - 0s - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 83/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0194 - val_root_mean_squared_error: 0.1394
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 84/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0759 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1524
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 85/1000
# 8/8 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0939 - val_loss: 0.0342 - val_root_mean_squared_error: 0.1849
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 86/1000
# 8/8 - 0s - loss: 0.0063 - root_mean_squared_error: 0.0795 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1562
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 87/1000
# 8/8 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1533
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 88/1000
# 8/8 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1431
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 89/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0760 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1423
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 90/1000
# 8/8 - 0s - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 91/1000
# 8/8 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1477
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 92/1000
# 8/8 - 0s - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1649
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 93/1000
# 8/8 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0716 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1474
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 94/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 95/1000
# 8/8 - 0s - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1329
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 96/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0702 - val_loss: 0.0192 - val_root_mean_squared_error: 0.1385
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 97/1000
# 8/8 - 0s - loss: 0.0045 - root_mean_squared_error: 0.0669 - val_loss: 0.0182 - val_root_mean_squared_error: 0.1350
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 98/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0684 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1341
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 99/1000
# 8/8 - 0s - loss: 0.0045 - root_mean_squared_error: 0.0673 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1370
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 100/1000
# 8/8 - 0s - loss: 0.0046 - root_mean_squared_error: 0.0676 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1341
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 101/1000
# 8/8 - 0s - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1332
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 102/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1345
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 103/1000
# 8/8 - 0s - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1314
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 104/1000
# 8/8 - 0s - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1336
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 105/1000
# 8/8 - 0s - loss: 0.0045 - root_mean_squared_error: 0.0668 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1335
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 106/1000
# 8/8 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1340
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 107/1000
# 8/8 - 0s - loss: 0.0046 - root_mean_squared_error: 0.0681 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 108/1000
# 8/8 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1355
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 109/1000
# 8/8 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1369
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 110/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 111/1000
# 8/8 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1358
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 112/1000
# 8/8 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0764 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1413
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 113/1000
# 8/8 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0688 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1403
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 114/1000
# 8/8 - 0s - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 115/1000
# 8/8 - 0s - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 116/1000
# 8/8 - 0s - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 117/1000
# 8/8 - 0s - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1296
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 118/1000
# 8/8 - 0s - loss: 0.0041 - root_mean_squared_error: 0.0641 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 119/1000
# 8/8 - 0s - loss: 0.0042 - root_mean_squared_error: 0.0648 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 120/1000
# 8/8 - 0s - loss: 0.0041 - root_mean_squared_error: 0.0637 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 121/1000
# 8/8 - 0s - loss: 0.0041 - root_mean_squared_error: 0.0637 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 122/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0635 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1267
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 123/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0633 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 124/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0634 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 125/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0629 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 126/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0634 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1256
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 127/1000
# 8/8 - 0s - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 128/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0631 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 129/1000
# 8/8 - 0s - loss: 0.0039 - root_mean_squared_error: 0.0624 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1247
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 130/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0633 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 131/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0620 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1234
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 132/1000
# 8/8 - 0s - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1247
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 133/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 134/1000
# 8/8 - 0s - loss: 0.0039 - root_mean_squared_error: 0.0623 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1229
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 135/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0616 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 136/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 137/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0615 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 138/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0619 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 139/1000
# 8/8 - 0s - loss: 0.0037 - root_mean_squared_error: 0.0612 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 140/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0615 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 141/1000
# 8/8 - 0s - loss: 0.0037 - root_mean_squared_error: 0.0610 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1211
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 142/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0614 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 143/1000
# 8/8 - 0s - loss: 0.0037 - root_mean_squared_error: 0.0606 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1202
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 144/1000
# 8/8 - 0s - loss: 0.0037 - root_mean_squared_error: 0.0609 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 145/1000
# 8/8 - 0s - loss: 0.0036 - root_mean_squared_error: 0.0603 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 146/1000
# 8/8 - 0s - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1193
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 147/1000
# 8/8 - 0s - loss: 0.0036 - root_mean_squared_error: 0.0599 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 148/1000
# 8/8 - 0s - loss: 0.0036 - root_mean_squared_error: 0.0602 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 149/1000
# 8/8 - 0s - loss: 0.0036 - root_mean_squared_error: 0.0596 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1186
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 150/1000
# 8/8 - 0s - loss: 0.0036 - root_mean_squared_error: 0.0600 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1181
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 151/1000
# 8/8 - 0s - loss: 0.0035 - root_mean_squared_error: 0.0593 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1179
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 152/1000
# 8/8 - 0s - loss: 0.0035 - root_mean_squared_error: 0.0595 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1177
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 153/1000
# 8/8 - 0s - loss: 0.0035 - root_mean_squared_error: 0.0589 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1173
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 154/1000
# 8/8 - 0s - loss: 0.0035 - root_mean_squared_error: 0.0592 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 155/1000
# 8/8 - 0s - loss: 0.0034 - root_mean_squared_error: 0.0586 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 156/1000
# 8/8 - 0s - loss: 0.0034 - root_mean_squared_error: 0.0587 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1162
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 157/1000
# 8/8 - 0s - loss: 0.0034 - root_mean_squared_error: 0.0582 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1160
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 158/1000
# 8/8 - 0s - loss: 0.0034 - root_mean_squared_error: 0.0584 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 159/1000
# 8/8 - 0s - loss: 0.0034 - root_mean_squared_error: 0.0579 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 160/1000
# 8/8 - 0s - loss: 0.0034 - root_mean_squared_error: 0.0579 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 161/1000
# 8/8 - 0s - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 162/1000
# 8/8 - 0s - loss: 0.0033 - root_mean_squared_error: 0.0576 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 163/1000
# 8/8 - 0s - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 164/1000
# 8/8 - 0s - loss: 0.0033 - root_mean_squared_error: 0.0572 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 165/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0568 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 166/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1125
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 167/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 168/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0567 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 169/1000
# 8/8 - 0s - loss: 0.0031 - root_mean_squared_error: 0.0560 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 170/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 171/1000
# 8/8 - 0s - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 172/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0564 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 173/1000
# 8/8 - 0s - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 174/1000
# 8/8 - 0s - loss: 0.0032 - root_mean_squared_error: 0.0562 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 175/1000
# 8/8 - 0s - loss: 0.0030 - root_mean_squared_error: 0.0548 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 176/1000
# 8/8 - 0s - loss: 0.0031 - root_mean_squared_error: 0.0559 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 177/1000
# 8/8 - 0s - loss: 0.0030 - root_mean_squared_error: 0.0544 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 178/1000
# 8/8 - 0s - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1079
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 179/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0541 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1064
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 180/1000
# 8/8 - 0s - loss: 0.0030 - root_mean_squared_error: 0.0548 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1065
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 181/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 182/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0542 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1051
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 183/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0534 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 184/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 185/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 186/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 187/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 188/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 189/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0536 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 190/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 191/1000
# 8/8 - 0s - loss: 0.0030 - root_mean_squared_error: 0.0547 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 192/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0543 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 193/1000
# 8/8 - 0s - loss: 0.0042 - root_mean_squared_error: 0.0649 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 194/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0614 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1057
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 195/1000
# 8/8 - 0s - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 196/1000
# 8/8 - 0s - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0190 - val_root_mean_squared_error: 0.1378
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 197/1000
# 8/8 - 0s - loss: 0.0040 - root_mean_squared_error: 0.0634 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 198/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0614 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1194
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 199/1000
# 8/8 - 0s - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 200/1000
# 8/8 - 0s - loss: 0.0035 - root_mean_squared_error: 0.0594 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 201/1000
# 8/8 - 0s - loss: 0.0042 - root_mean_squared_error: 0.0644 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 202/1000
# 8/8 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0740 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1364
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 203/1000
# 8/8 - 0s - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1189
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 204/1000
# 8/8 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1302
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 205/1000
# 8/8 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0730 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 206/1000
# 8/8 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 207/1000
# 8/8 - 0s - loss: 0.0038 - root_mean_squared_error: 0.0620 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 208/1000
# 8/8 - 0s - loss: 0.0039 - root_mean_squared_error: 0.0622 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1064
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 209/1000
# 8/8 - 0s - loss: 0.0033 - root_mean_squared_error: 0.0575 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 210/1000
# 8/8 - 0s - loss: 0.0030 - root_mean_squared_error: 0.0546 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 211/1000
# 8/8 - 0s - loss: 0.0031 - root_mean_squared_error: 0.0558 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1079
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 212/1000
# 8/8 - 0s - loss: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 213/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1024
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 214/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1030
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 215/1000
# 8/8 - 0s - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 216/1000
# 8/8 - 0s - loss: 0.0027 - root_mean_squared_error: 0.0521 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1025
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 217/1000
# 8/8 - 0s - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 218/1000
# 8/8 - 0s - loss: 0.0027 - root_mean_squared_error: 0.0517 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 219/1000
# 8/8 - 0s - loss: 0.0026 - root_mean_squared_error: 0.0510 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 220/1000
# 8/8 - 0s - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 221/1000
# 8/8 - 0s - loss: 0.0026 - root_mean_squared_error: 0.0506 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 222/1000
# 8/8 - 0s - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 223/1000
# 8/8 - 0s - loss: 0.0025 - root_mean_squared_error: 0.0505 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 224/1000
# 8/8 - 0s - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 225/1000
# 8/8 - 0s - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 226/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# ...
# 8/8 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1151
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 928/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 929/1000
# 8/8 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1395
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 930/1000
# 8/8 - 0s - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 931/1000
# 8/8 - 0s - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 932/1000
# 8/8 - 0s - loss: 0.0028 - root_mean_squared_error: 0.0527 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 933/1000
# 8/8 - 0s - loss: 0.0024 - root_mean_squared_error: 0.0487 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0962
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 934/1000
# 8/8 - 0s - loss: 0.0017 - root_mean_squared_error: 0.0418 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0607
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 935/1000
# 8/8 - 0s - loss: 0.0018 - root_mean_squared_error: 0.0420 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 936/1000
# 8/8 - 0s - loss: 0.0012 - root_mean_squared_error: 0.0346 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0437
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 937/1000
# 8/8 - 0s - loss: 0.0011 - root_mean_squared_error: 0.0325 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0432
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 938/1000
# 8/8 - 0s - loss: 8.9529e-04 - root_mean_squared_error: 0.0299 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0403
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 939/1000
# 8/8 - 0s - loss: 8.2445e-04 - root_mean_squared_error: 0.0287 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0385
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 940/1000
# 8/8 - 0s - loss: 7.8997e-04 - root_mean_squared_error: 0.0281 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0386
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 941/1000
# 8/8 - 0s - loss: 7.4115e-04 - root_mean_squared_error: 0.0272 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0384
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 942/1000
# 8/8 - 0s - loss: 7.2010e-04 - root_mean_squared_error: 0.0268 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0382
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 943/1000
# 8/8 - 0s - loss: 6.9965e-04 - root_mean_squared_error: 0.0265 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0378
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 944/1000
# 8/8 - 0s - loss: 6.8539e-04 - root_mean_squared_error: 0.0262 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0377
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 945/1000
# 8/8 - 0s - loss: 6.7212e-04 - root_mean_squared_error: 0.0259 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0374
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 946/1000
# 8/8 - 0s - loss: 6.6167e-04 - root_mean_squared_error: 0.0257 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0371
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 947/1000
# 8/8 - 0s - loss: 6.5203e-04 - root_mean_squared_error: 0.0255 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0369
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 948/1000
# 8/8 - 0s - loss: 6.4258e-04 - root_mean_squared_error: 0.0253 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0366
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 949/1000
# 8/8 - 0s - loss: 6.3429e-04 - root_mean_squared_error: 0.0252 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0364
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 950/1000
# 8/8 - 0s - loss: 6.2630e-04 - root_mean_squared_error: 0.0250 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0362
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 951/1000
# 8/8 - 0s - loss: 6.1912e-04 - root_mean_squared_error: 0.0249 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0359
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 952/1000
# 8/8 - 0s - loss: 6.1181e-04 - root_mean_squared_error: 0.0247 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0357
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 953/1000
# 8/8 - 0s - loss: 6.0563e-04 - root_mean_squared_error: 0.0246 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0356
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 954/1000
# 8/8 - 0s - loss: 5.9887e-04 - root_mean_squared_error: 0.0245 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0354
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 955/1000
# 8/8 - 0s - loss: 5.9349e-04 - root_mean_squared_error: 0.0244 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 956/1000
# 8/8 - 0s - loss: 5.8708e-04 - root_mean_squared_error: 0.0242 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0350
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 957/1000
# 8/8 - 0s - loss: 5.8242e-04 - root_mean_squared_error: 0.0241 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0349
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 958/1000
# 8/8 - 0s - loss: 5.7621e-04 - root_mean_squared_error: 0.0240 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 959/1000
# 8/8 - 0s - loss: 5.7218e-04 - root_mean_squared_error: 0.0239 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 960/1000
# 8/8 - 0s - loss: 5.6608e-04 - root_mean_squared_error: 0.0238 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0345
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 961/1000
# 8/8 - 0s - loss: 5.6255e-04 - root_mean_squared_error: 0.0237 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 962/1000
# 8/8 - 0s - loss: 5.5658e-04 - root_mean_squared_error: 0.0236 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 963/1000
# 8/8 - 0s - loss: 5.5334e-04 - root_mean_squared_error: 0.0235 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 964/1000
# 8/8 - 0s - loss: 5.4766e-04 - root_mean_squared_error: 0.0234 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 965/1000
# 8/8 - 0s - loss: 5.4450e-04 - root_mean_squared_error: 0.0233 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 966/1000
# 8/8 - 0s - loss: 5.3942e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0339
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 967/1000
# 8/8 - 0s - loss: 5.3612e-04 - root_mean_squared_error: 0.0232 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0338
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 968/1000
# 8/8 - 0s - loss: 5.3197e-04 - root_mean_squared_error: 0.0231 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0337
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 969/1000
# 8/8 - 0s - loss: 5.2830e-04 - root_mean_squared_error: 0.0230 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0336
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 970/1000
# 8/8 - 0s - loss: 5.2513e-04 - root_mean_squared_error: 0.0229 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 971/1000
# 8/8 - 0s - loss: 5.2101e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 972/1000
# 8/8 - 0s - loss: 5.1833e-04 - root_mean_squared_error: 0.0228 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 973/1000
# 8/8 - 0s - loss: 5.1425e-04 - root_mean_squared_error: 0.0227 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0333
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 974/1000
# 8/8 - 0s - loss: 5.1145e-04 - root_mean_squared_error: 0.0226 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 975/1000
# 8/8 - 0s - loss: 5.0830e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 976/1000
# 8/8 - 0s - loss: 5.0485e-04 - root_mean_squared_error: 0.0225 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 977/1000
# 8/8 - 0s - loss: 5.0280e-04 - root_mean_squared_error: 0.0224 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0330
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 978/1000
# 8/8 - 0s - loss: 4.9877e-04 - root_mean_squared_error: 0.0223 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 979/1000
# 8/8 - 0s - loss: 4.9678e-04 - root_mean_squared_error: 0.0223 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 980/1000
# 8/8 - 0s - loss: 4.9354e-04 - root_mean_squared_error: 0.0222 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 981/1000
# 8/8 - 0s - loss: 4.9080e-04 - root_mean_squared_error: 0.0222 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0327
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 982/1000
# 8/8 - 0s - loss: 4.8968e-04 - root_mean_squared_error: 0.0221 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0327
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 983/1000
# 8/8 - 0s - loss: 4.8560e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 984/1000
# 8/8 - 0s - loss: 4.8442e-04 - root_mean_squared_error: 0.0220 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0326
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 985/1000
# 8/8 - 0s - loss: 4.8088e-04 - root_mean_squared_error: 0.0219 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 986/1000
# 8/8 - 0s - loss: 4.7916e-04 - root_mean_squared_error: 0.0219 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0324
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 987/1000
# 8/8 - 0s - loss: 4.7975e-04 - root_mean_squared_error: 0.0219 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 988/1000
# 8/8 - 0s - loss: 4.7563e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0324
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 989/1000
# 8/8 - 0s - loss: 4.7470e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0324
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 990/1000
# 8/8 - 0s - loss: 4.7033e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 991/1000
# 8/8 - 0s - loss: 4.7018e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0321
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 992/1000
# 8/8 - 0s - loss: 4.7393e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0324
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 993/1000
# 8/8 - 0s - loss: 4.6984e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 994/1000
# 8/8 - 0s - loss: 4.6763e-04 - root_mean_squared_error: 0.0216 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 995/1000
# 8/8 - 0s - loss: 4.6115e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0320
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 996/1000
# 8/8 - 0s - loss: 4.6364e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 997/1000
# 8/8 - 0s - loss: 4.7263e-04 - root_mean_squared_error: 0.0217 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 998/1000
# 8/8 - 0s - loss: 4.6831e-04 - root_mean_squared_error: 0.0216 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0320
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 999/1000
# 8/8 - 0s - loss: 4.6211e-04 - root_mean_squared_error: 0.0215 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 1000/1000
# 8/8 - 0s - loss: 4.5217e-04 - root_mean_squared_error: 0.0213 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_months*n_features))

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -5:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -5:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real Chinook Count')
    plt.plot(predicted, color='blue',label='Predicted Chinook Count')
    plt.title('Chinook Population Prediction')
    plt.xlabel('Time')
    plt.ylabel('Chinook Count')
    plt.legend()
    plt.show()
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()
def month_to_year(month_preds):
    month_preds = month_preds[6:]
    year_preds = []
    for i in range(12, len(month_preds) + 1, 12):   
        salmon_count = np.sum(month_preds[i - 12:i])
        year_preds.append(salmon_count)
    year_preds = pd.DataFrame(year_preds, columns = ["Count"])
    return year_preds

def return_rmse(test, predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The test root mean squared error is {}.".format(rmse))

# %%
plot_predictions(inv_y, inv_yhat)
return_rmse(inv_y, inv_yhat)
# Out:
# The Test root mean squared error is 66355.97576707014.

# %%
plot_loss(history)

# %%
preds = month_to_year(inv_yhat).astype(np.int64)
actual = month_to_year(inv_y).astype(np.int64)
print(preds)
print(actual)
# Out:
#     Count
# 0  530716
# 1  368559
# 2  419847
# 3  313774
#     Count
# 0  488981
# 1  336030
# 2  381773
# 3  535746

# %%
bs_chris_path = '/Users/chrisshell/Desktop/Stanford/SalmonData/Use Data/Forecast Data Update.csv'
bs_ismael_path = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/forecast_data_17_20.csv'
bs_abdul_path = '/Users/abdul/Downloads/SalmonNet/Forecast Data Update.csv'
baseline_data = pd.read_csv(bs_chris_path)
traditional = pd.DataFrame(baseline_data["Count"])
print(traditional)
# Out:
#     Count
# 0  498710
# 1  439060
# 2  294840
# 3  347600

# %%
return_rmse(actual, traditional)
# Out:
# The Test root mean squared error is 115829.72216361394.

# %%
return_rmse(actual, preds)
# Out:
# The Test root mean squared error is 115673.1865278207.

# %%
# def create_train_test(king_all):
#     king_training_parse = king_all['date'].apply(pd.Timestamp) <= pd.Timestamp('12/31/2015')
#     king_training = king_all[king_training_parse]
#     king_training = king_training.reset_index()
#     king_training = king_training.drop('index', axis=1)
    
#     king_test_parse = king_all['date'].apply(pd.Timestamp) > pd.Timestamp('12/31/2015')
#     king_test = king_all[king_test_parse]
#     king_test = king_test.reset_index()
#     king_test = king_test.drop('index', axis=1)
#     print(king_test.shape)
    
#     # Normalizing Data
#     king_training[king_training["king"] < 0] = 0 
# #     print('max val king_train:')
#     print(max(king_training['king']))
#     king_test[king_test["king"] < 0] = 0
# #     print('max val king_test:')
#     print(max(king_test['king']))
#     king_train_pre = king_training["king"].to_frame()
# #     print(king_train_norm)
#     king_test_pre = king_test["king"].to_frame()
#     scaler = MinMaxScaler(feature_range=(0, 1))
#     king_train_norm = scaler.fit_transform(king_train_pre)
#     king_test_norm = scaler.fit_transform(king_test_pre)
#     print('king_test_norm')
#     print(king_test_norm.shape)
#     print('king_train_norm')
#     print(king_train_norm.shape)
#     #king_train_norm = (king_training["king"] - np.min(king_training["king"])) / (np.max(king_training["king"]) - np.min(king_training["king"]))
#     #print(type(king_train_norm))
#     #king_train_norm = king_train_norm.to_frame()
#     x_train = []
#     y_train = []
#     x_test = []
#     y_test = []
#     y_test_not_norm = []
#     y_train_not_norm = []
    
#     # Todo: Experiment with input size of input (ex. 30 days)
    
#     for i in range(6,924): # 30
#         x_train.append(king_train_norm[i-6:i])
#         y_train.append(king_train_norm[i])
#     for i in range(6, 60):
#         x_test.append(king_test_norm[i-6:i])
#         y_test.append(king_test_norm[i])
    
#     # make y_test_not_norm
#     for i in range(6, 60):
#         y_test_not_norm.append(king_test['king'][i])
#     for i in range(6,924): # 30
#         y_train_not_norm.append(king_training['king'][i])
        
#     return x_train, y_train, x_test, y_test, scaler, y_test_not_norm, y_train_not_norm

# %%
x_train, y_train, x_test, y_test, scaler, y_test_not_norm, y_train_not_norm = create_train_test(data_copy)
x_train = np.array(x_train)
x_test = np.array(x_test)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1)).astype(np.float32)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
y_train = np.array(y_train)
y_test = np.array(y_test)
y_test_not_norm = np.array(y_test_not_norm)
print(y_test.shape)
y_test_not_norm = y_test_not_norm.reshape((y_test_not_norm.shape[0], 1))
print(y_test_not_norm.shape)
y_train_not_norm = np.array(y_train_not_norm)
y_train_not_norm = y_train_not_norm.reshape((y_train_not_norm.shape[0], 1))
print(y_train_not_norm.shape)
print(y_train.shape)
# Out:
# (60, 2)
# 717915
# 294611
# king_test_norm
# (60, 1)
# king_train_norm
# (924, 1)
# (54, 1)
# (54, 1)
# (918, 1)
# (918, 1)

# %%
# def load_pdo(pathname):
#     pdo_data = pd.read_csv(pathname)
# #     print(pdo_data.head())
#     return pdo_data

# %%
# ismael_path_pdo = '/Users/ismaelcastro/Documents/Computer Science/CS Classes/CS230/project/pdo.csv'
# pdo_data = load_pdo(ismael_path_pdo)

# %%
# pdo = pdo_data["PDO"]
# data_copy = data_copy.join(pdo)

# %%
# pdo_data

# %%
# print(data_copy)
